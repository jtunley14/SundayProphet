# %% [markdown]
# # NFL Sports Betting Capstone: Automated In-Season Data Scraper
# _By Justin Tunley_

# %% [markdown]
# My first notebook for this project was pulling the historical data for teams between 2004-2022 from ESPN. This notebook focuses on pulling that same data from ESPN, but only for in-season data.
#
# IMPORTANT FOR ACCURATE RESULTS: as the season continues and new games are played, the data being pulled is going to change on ESPN. This notebook will automatically update and format the new information properly, so long as you re-run the notebook. This means re-scraping from ESPN, rerunning all of the preprocessing and cleaning steps, and re-importing your new CSV. Remember: if you do not rerun this whole notebook, you will have outdated data.
#
# If this notebook looks similar, it is because I duplicated the historical data notebook and changed the scraping method to grab something different. Everything else is essentially the same.

# %%
# %pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /Users/justintunley/anaconda3/lib/python3.11/site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/justintunley/anaconda3/lib/python3.11/site-packages (from beautifulsoup4) (2.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install html5lib
# Out:
# Requirement already satisfied: html5lib in /Users/justintunley/anaconda3/lib/python3.11/site-packages (1.1)
# Requirement already satisfied: six>=1.9 in /Users/justintunley/anaconda3/lib/python3.11/site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in /Users/justintunley/anaconda3/lib/python3.11/site-packages (from html5lib) (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sportsreference as csr
import html5lib

import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Scraping from ESPN
# #### This will be used for the bulk of our information

# %%
jets23 = pd.read_html('https://www.espn.com/nfl/team/stats/_/type/team/name/nyj')
# scraping data for THIS SEASON for the New York Jets

# %%
jets23[1].index = list(str(x[0]) for x in jets23[0].values)
jets23[1]
# 4 Goals: 
#    1. Split up offensive and defensive stats
#    2. Get each into a single row
#    3. Renaming columns
#    4. Dropping header rows
# Out:
#                                NY Jets Opponents
# Total Points Per Game             14.8      21.6
# Total Points                       163       238
# Total Touchdowns                    13        22
# 1st Downs                          NaN       NaN
# Total 1st downs                    159       213
# Rushing 1st downs                   44        80
# Passing 1st downs                   98       109
# 1st downs by penalty                17        24
# 3rd down efficiency             35-145    70-165
# 3rd down %                       24.14     42.42
# 4th down efficiency              12-18       4-6
# 4th down %                       66.67     66.67
# Passing                            NaN       NaN
# Comp-Att                       225-376   220-347
# Net Passing Yards                 1835      2015
# Yards Per Pass Attempt             5.8       6.3
# Net Passing Yards Per Game       166.8     183.2
# Passing Touchdowns                   7        13
# Interceptions                       10        12
# Sacks-Yards Lost                47-339    28-170
# Rushing                            NaN       NaN
# Rushing Attempts                   226       365
# Rushing Yards                     1027      1543
# Yards Per Rush Attempt             4.5       4.2
# Rushing Yards Per Game            93.4     140.3
# Rushing Touchdowns                   3         7
# Offense                            NaN       NaN
# Total Offensive Plays              649       740
# Total Yards                       3201      3728
# Yards Per Game                   291.0     338.9
# Returns                            NaN       NaN
# Kickoffs: Total                 14-302      5-82
# Average Kickoff Return Yards      21.6      16.4
# Punt: Total                     17-170    31-352
# Average Punt Return Yards         11.4      10.0
# INT: Total                      12-145    10-186
# Average Interception Yards        12.1      18.6
# Kicking                            NaN       NaN
# Net Average Punt Yards            43.9      40.7
# Punt: Total Yards             64-3,160  52-2,288
# FG: Good-Attempts                23-24     27-32
# Touchback Percentage                83        75
# Penalties                          NaN       NaN
# Total-Yards                     71-538    58-496
# Avg. Per Game (YDS)                 48    45.091
# Time of Possession                 NaN       NaN
# Possession Time Seconds          27:31     32:55
# Miscellaneous                      NaN       NaN
# Fumbles-Lost                     20-10      20-7
# Turnover Ratio                      -1       142

# %% [markdown]
# **Link to in-season data:**<br>
#
# Jets 2023: https://www.espn.com/nfl/team/stats/_/type/team/name/nyj
#
# Template: https://www.espn.com/nfl/team/stats/_/type/team/name/ ... **abbrev**
#
#
# **Link to historical data:**<br>
#
# Jets 2022: https://www.espn.com/nfl/team/stats/_/type/team/name/nyj/season/2022/seasontype/2
#
# Template: https://www.espn.com/nfl/team/stats/_/type/team/name/ **team** /season/  **year**  /seasontype/2

# %%
big_string='''
Cardinals - ari <br>
Falcons - atl <br>
Ravens - bal<br>
Bills - buf<br>
Panthers - car<br>
Bears - chi<br>
Bengals - cin<br>
Browns - cle<br>
Cowboys - dal<br>
Broncos - den<br>
Lions - det<br>
Packers - gb<br>
Texans - hou<br>
Colts - ind<br>
Jaguars - jax<br>
Chiefs - kc<br>
Raiders - lv<br>
Chargers - lac<br>
Rams - lar<br>
Dolphins - mia<br>
Vikings - min<br>
Patriots - ne<br>
Saints - no<br>
Giants - nyg<br>
Jets - nyj<br>
Eagles - phi<br>
Steelers - pit<br>
49ers - sf<br>
Seahawks - sea<br>
Buccaneers - tb<br>
Titans - ten<br>
Commanders - wsh
'''

# %%
abbrev = big_string.replace('<br>', '').split()[2::3]
abbrev
# Out:
# ['ari',
#  'atl',
#  'bal',
#  'buf',
#  'car',
#  'chi',
#  'cin',
#  'cle',
#  'dal',
#  'den',
#  'det',
#  'gb',
#  'hou',
#  'ind',
#  'jax',
#  'kc',
#  'lv',
#  'lac',
#  'lar',
#  'mia',
#  'min',
#  'ne',
#  'no',
#  'nyg',
#  'nyj',
#  'phi',
#  'pit',
#  'sf',
#  'sea',
#  'tb',
#  'ten',
#  'wsh']

# %%
# def get_season_df(team,season):
#         template = 'https://www.espn.com/nfl/team/stats/_/type/team/name/nyj/season/2022/seasontype/2'
#         url = template.format(team,season)
#         df_list = pd.read_html(url)
#         df_list[1].index=list(str(x[0]) for x in df_list[0].values)
#         new_columns = ['Offense--{}-{}'.format(team,season),'Opposing-offense-{}-{}'.format(team,season)]
#         df_list[1].columns = new_columns
#         return df_list[1]

# Repeats Arizona 2004 in every single row: break up string




# https://www.espn.com/nfl/team/stats/_/type/team/name/nyj

# %%
def get_season_df(team,season):
        template1 = 'https://www.espn.com/nfl/team/stats/_/type/team/name/'
        url = template1 + team
        print(url)
        df_list = pd.read_html(url)
#         curr_season = pull current year from datatime.year()
        
        df_list[1].index=list(str(x[0]) for x in df_list[0].values)
        new_columns = ['Offense--{}-2023'.format(team),'Opposing-offense-{}-2023'.format(team)]
        df_list[1].columns = new_columns
        return df_list[1]

# %%
year = 2023

# %%
all_df = []
for team in abbrev:
        new_df = get_season_df(team, year)
        all_df.append(new_df)
# Out:
# https://www.espn.com/nfl/team/stats/_/type/team/name/ari
# https://www.espn.com/nfl/team/stats/_/type/team/name/atl
# https://www.espn.com/nfl/team/stats/_/type/team/name/bal
# https://www.espn.com/nfl/team/stats/_/type/team/name/buf
# https://www.espn.com/nfl/team/stats/_/type/team/name/car
# https://www.espn.com/nfl/team/stats/_/type/team/name/chi
# https://www.espn.com/nfl/team/stats/_/type/team/name/cin
# https://www.espn.com/nfl/team/stats/_/type/team/name/cle
# https://www.espn.com/nfl/team/stats/_/type/team/name/dal
# https://www.espn.com/nfl/team/stats/_/type/team/name/den
# https://www.espn.com/nfl/team/stats/_/type/team/name/det
# https://www.espn.com/nfl/team/stats/_/type/team/name/gb
# https://www.espn.com/nfl/team/stats/_/type/team/name/hou
# https://www.espn.com/nfl/team/stats/_/type/team/name/ind
# https://www.espn.com/nfl/team/stats/_/type/team/name/jax
# https://www.espn.com/nfl/team/stats/_/type/team/name/kc
# https://www.espn.com/nfl/team/stats/_/type/team/name/lv
# https://www.espn.com/nfl/team/stats/_/type/team/name/lac
# https://www.espn.com/nfl/team/stats/_/type/team/name/lar
# https://www.espn.com/nfl/team/stats/_/type/team/name/mia
# https://www.espn.com/nfl/team/stats/_/type/team/name/min
# https://www.espn.com/nfl/team/stats/_/type/team/name/ne
# https://www.espn.com/nfl/team/stats/_/type/team/name/no
# https://www.espn.com/nfl/team/stats/_/type/team/name/nyg
# https://www.espn.com/nfl/team/stats/_/type/team/name/nyj
# https://www.espn.com/nfl/team/stats/_/type/team/name/phi
# https://www.espn.com/nfl/team/stats/_/type/team/name/pit
# https://www.espn.com/nfl/team/stats/_/type/team/name/sf
# https://www.espn.com/nfl/team/stats/_/type/team/name/sea
# https://www.espn.com/nfl/team/stats/_/type/team/name/tb
# https://www.espn.com/nfl/team/stats/_/type/team/name/ten
# https://www.espn.com/nfl/team/stats/_/type/team/name/wsh

# %%
current_season_df = pd.concat(all_df, axis=1).T
current_season_df.head()
# Out:
#                           Total Points Per Game Total Points Total Touchdowns  \
# Offense--ari-2023                          17.2          206               22
# Opposing-offense-ari-2023                  26.8          321               38
# Offense--atl-2023                          19.4          213               21
# Opposing-offense-atl-2023                  21.1          232               22
# Offense--bal-2023                          27.0          324               37
#
#                           1st Downs Total 1st downs Rushing 1st downs  \
# Offense--ari-2023               NaN             218                76
# Opposing-offense-ari-2023       NaN             270               101
# Offense--atl-2023               NaN             224                90
# Opposing-offense-atl-2023       NaN             204                61
# Offense--bal-2023               NaN             251               108
#
#                           Passing 1st downs 1st downs by penalty  \
# Offense--ari-2023                       118                   24
# Opposing-offense-ari-2023               146                   23
# Offense--atl-2023                       119                   15
# Opposing-offense-atl-2023               120                   23
# Offense--bal-2023                       116                   27
#
#                           3rd down efficiency 3rd down %  ...  \
# Offense--ari-2023                      54-153      35.29  ...
# Opposing-offense-ari-2023              71-151      47.02  ...
# Offense--atl-2023                      62-148      41.89  ...
# Opposing-offense-atl-2023              50-142      35.21  ...
# Offense--bal-2023                      66-152      43.42  ...
#
#                           FG: Good-Attempts Touchback Percentage Penalties  \
# Offense--ari-2023                     19-22                   84       NaN
# Opposing-offense-ari-2023             19-23                   82       NaN
# Offense--atl-2023                     22-23                   85       NaN
# Opposing-offense-atl-2023             26-27                   81       NaN
# Offense--bal-2023                     21-26                   84       NaN
#
#                           Total-Yards Avg. Per Game (YDS) Time of Possession  \
# Offense--ari-2023              79-720                  60                NaN
# Opposing-offense-ari-2023      73-599              49.917                NaN
# Offense--atl-2023              59-528                  48                NaN
# Opposing-offense-atl-2023      73-600              54.545                NaN
# Offense--bal-2023              73-684                  57                NaN
#
#                           Possession Time Seconds Miscellaneous Fumbles-Lost  \
# Offense--ari-2023                           27:46           NaN         12-6
# Opposing-offense-ari-2023                   32:13           NaN          7-5
# Offense--atl-2023                           30:17           NaN         11-9
# Opposing-offense-atl-2023                   29:42           NaN         12-6
# Offense--bal-2023                           31:49           NaN         19-9
#
#                           Turnover Ratio
# Offense--ari-2023                     -1
# Opposing-offense-ari-2023            161
# Offense--atl-2023                     -6
# Opposing-offense-atl-2023            140
# Offense--bal-2023                      5
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Data Preprocessing and Cleaning

# %%
current_season_df.shape
# MAKE SURE YOU ARE COMPLETELY DONE SCRAPING BEFORE CONCATENATING
# YOU WILL NOT GET AN ERROR MESSAGE, YOU WILL JUST BE MISSING ROWS. MAKE SURE SHAPE IS 1216 X 50
# Out:
# (64, 50)

# %%
pd.set_option('display.max_columns',None)
# so that we can view all columns

# %%
current_season_df.tail()
# not organized by year, so can't just grab the last 'x' rows
# Out:
#                           Total Points Per Game Total Points Total Touchdowns  \
# Opposing-offense-tb-2023                   20.6          227               23
# Offense--ten-2023                          16.8          185               17
# Opposing-offense-ten-2023                  20.4          224               20
# Offense--wsh-2023                          20.5          246               27
# Opposing-offense-wsh-2023                  29.2          350               39
#
#                           1st Downs Total 1st downs Rushing 1st downs  \
# Opposing-offense-tb-2023        NaN             227                66
# Offense--ten-2023               NaN             184                59
# Opposing-offense-ten-2023       NaN             213                68
# Offense--wsh-2023               NaN             254                75
# Opposing-offense-wsh-2023       NaN             236                71
#
#                           Passing 1st downs 1st downs by penalty  \
# Opposing-offense-tb-2023                146                   15
# Offense--ten-2023                        95                   30
# Opposing-offense-ten-2023               120                   25
# Offense--wsh-2023                       154                   25
# Opposing-offense-wsh-2023               149                   16
#
#                           3rd down efficiency 3rd down % 4th down efficiency  \
# Opposing-offense-tb-2023               65-146      44.52                7-14
# Offense--ten-2023                      42-132      31.82                7-12
# Opposing-offense-ten-2023              60-151      39.74               10-15
# Offense--wsh-2023                      60-157      38.22                8-17
# Opposing-offense-wsh-2023              64-162      39.51                9-15
#
#                           4th down % Passing Comp-Att Net Passing Yards  \
# Opposing-offense-tb-2023       50.00     NaN  270-405              2946
# Offense--ten-2023              58.33     NaN  194-317              1994
# Opposing-offense-ten-2023      66.67     NaN  237-349              2470
# Offense--wsh-2023              47.06     NaN  323-486              2964
# Opposing-offense-wsh-2023      60.00     NaN  269-423              3175
#
#                           Yards Per Pass Attempt Net Passing Yards Per Game  \
# Opposing-offense-tb-2023                     7.8                      267.8
# Offense--wsh-2023                     17-21                   96       NaN
# Opposing-offense-wsh-2023             26-27                   76       NaN
#
#                           Total-Yards Avg. Per Game (YDS) Time of Possession  \
# Opposing-offense-tb-2023       70-588              53.455                NaN
# Offense--ten-2023              69-558                  50                NaN
# Opposing-offense-ten-2023      66-526              47.818                NaN
# Offense--wsh-2023              64-495                  41                NaN
# Opposing-offense-wsh-2023      73-586              48.833                NaN
#
#                           Possession Time Seconds Miscellaneous Fumbles-Lost  \
# Opposing-offense-tb-2023                    30:47           NaN         13-8
# Offense--ten-2023                           29:04           NaN          8-4
# Opposing-offense-ten-2023                   31:22           NaN         11-5
# Offense--wsh-2023                           31:41           NaN         16-9
# Opposing-offense-wsh-2023                   28:48           NaN         12-7
#
#                           Turnover Ratio
# Opposing-offense-tb-2023             157
# Offense--ten-2023                     -4
# Opposing-offense-ten-2023            175
# Offense--wsh-2023                     -9
# Opposing-offense-wsh-2023            132

# %%
current_season_df.columns
# Out:
# Index(['Total Points Per Game', 'Total Points', 'Total Touchdowns',
#        '1st Downs', 'Total 1st downs', 'Rushing 1st downs',
#        'Passing 1st downs', '1st downs by penalty', '3rd down efficiency',
#        '3rd down %', '4th down efficiency', '4th down %', 'Passing',
#        'Comp-Att', 'Net Passing Yards', 'Yards Per Pass Attempt',
#        'Net Passing Yards Per Game', 'Passing Touchdowns', 'Interceptions',
#        'Sacks-Yards Lost', 'Rushing', 'Rushing Attempts', 'Rushing Yards',
#        'Yards Per Rush Attempt', 'Rushing Yards Per Game',
#        'Rushing Touchdowns', 'Offense', 'Total Offensive Plays', 'Total Yards',
#        'Yards Per Game', 'Returns', 'Kickoffs: Total',
#        'Average Kickoff Return Yards', 'Punt: Total',
#        'Average Punt Return Yards', 'INT: Total', 'Average Interception Yards',
#        'Kicking', 'Net Average Punt Yards', 'Punt: Total Yards',
#        'FG: Good-Attempts', 'Touchback Percentage', 'Penalties', 'Total-Yards',
#        'Avg. Per Game (YDS)', 'Time of Possession', 'Possession Time Seconds',
#        'Miscellaneous', 'Fumbles-Lost', 'Turnover Ratio'],
#       dtype='object')

# %%
#setting index as a column instead for easy manipulation 
current_season_df = current_season_df.reset_index()
current_season_df.rename(columns={'index':'SeasonID'}, inplace=True) #renaming new column

# %%
current_season_df
# Out:
#                      SeasonID Total Points Per Game Total Points  \
# 0           Offense--ari-2023                  17.2          206
# 1   Opposing-offense-ari-2023                  26.8          321
# 2           Offense--atl-2023                  19.4          213
# 3   Opposing-offense-atl-2023                  21.1          232
# 4           Offense--bal-2023                  27.0          324
# ..                        ...                   ...          ...
# 59   Opposing-offense-tb-2023                  20.6          227
# 60          Offense--ten-2023                  16.8          185
# 61  Opposing-offense-ten-2023                  20.4          224
# 62          Offense--wsh-2023                  20.5          246
# 63  Opposing-offense-wsh-2023                  29.2          350
#
#    Total Touchdowns 1st Downs Total 1st downs Rushing 1st downs  \
# 0                22       NaN             218                76
# 1                38       NaN             270               101
# 2                21       NaN             224                90
# 3                22       NaN             204                61
# 4                37       NaN             251               108
# 59                   704        4207          382.5     NaN          15-277
# 60                   618        3376          306.9     NaN          13-264
# 61                   701        3899          354.5     NaN          19-415
# 62                   798        4500          375.0     NaN          17-455
# 63                   763        4687          390.6     NaN             0-0
#
#    Average Kickoff Return Yards Punt: Total Average Punt Return Yards  \
# 0                          18.0      21-207                      10.2
# 1                          21.0      32-325                       9.9
# 2                          17.5       16-88                      12.3
# 3                          21.9      20-245                       5.5
# 4                          19.1      22-276                      13.8
# ..                          ...         ...                       ...
# 59                         18.5      23-280                       9.2
# 60                         20.3      27-214                      11.1
# 61                         21.8      20-221                       7.9
# 62                         26.8      28-207                       8.5
# 63                          0.0      27-230                       7.4
#
#    INT: Total Average Interception Yards Kicking Net Average Punt Yards  \
# 0        9-98                       10.9     NaN                   42.0
# 1        9-41                        4.6     NaN                   43.2
# 2       6-124                       20.7     NaN                   42.4
# 3       9-139                       15.4     NaN                   45.9
# 4      11-171                       15.5     NaN                   40.8
# ..        ...                        ...     ...                    ...
# 59       7-31                        4.4     NaN                   44.3
# 60       3-38                       12.7     NaN                   48.4
# 61       8-67                        8.4     NaN                   41.6
# 62       6-26                        4.3     NaN                   42.6
# 63     13-198                       15.2     NaN                   44.3
#
#    Punt: Total Yards FG: Good-Attempts Touchback Percentage Penalties  \
# 0           48-2,343             19-22                   84       NaN
# 1           42-2,020             19-23                   82       NaN
# 2           46-2,196             22-23                   85       NaN
# 3           48-2,292             26-27                   81       NaN
# 4           47-2,260             21-26                   84       NaN
# ..               ...               ...                  ...       ...
# 59          38-1,831             22-25                   70       NaN
# 60          49-2,594             22-23                   53       NaN
# 61          46-2,128             28-28                   67       NaN
# 62          52-2,444             17-21                   96       NaN
# 63          48-2,334             26-27                   76       NaN
#
#    Total-Yards Avg. Per Game (YDS) Time of Possession Possession Time Seconds  \
# 0       79-720                  60                NaN                   27:46
# 1       73-599              49.917                NaN                   32:13
# 2       59-528                  48                NaN                   30:17
# 3       73-600              54.545                NaN                   29:42
# 4       73-684                  57                NaN                   31:49
# ..         ...                 ...                ...                     ...
# 59      70-588              53.455                NaN                   30:47
# 60      69-558                  50                NaN                   29:04
# 61      66-526              47.818                NaN                   31:22
# 62      64-495                  41                NaN                   31:41
# 63      73-586              48.833                NaN                   28:48
#
#    Miscellaneous Fumbles-Lost Turnover Ratio
# 0            NaN         12-6             -1
# 1            NaN          7-5            161
# 2            NaN         11-9             -6
# 3            NaN         12-6            140
# 4            NaN         19-9              5
# ..           ...          ...            ...
# 59           NaN         13-8            157
# 60           NaN          8-4             -4
# 61           NaN         11-5            175
# 62           NaN         16-9             -9
# 63           NaN         12-7            132
#
# [64 rows x 51 columns]

# %%
current_season_df['Games'] = 17
# Set all current season to 17 games

# %%
# Currently, each team has 2 rows per season, one displaying offense and one displaying opposing offense (defense)
# We will be combining these into one row per team.

# %%
# New dataframe for just the offense
offDF = current_season_df.loc[current_season_df['SeasonID'].str.contains('Offense--'),:]

# %%
# New dataframe for just the defense
defDF = current_season_df.loc[current_season_df['SeasonID'].str.contains('Opposing-'),:]

# 0                    732        3811          317.6     NaN          10-180
# 1                    725        3960          360.0     NaN          11-193
# 2                    761        4559          379.9     NaN           8-153
# 3                    780        4682          390.2     NaN          11-239
# 4                    719        3264          296.7     NaN          15-447
# 5                    776        4098          341.5     NaN          14-299
# 6                    657        3438          312.5     NaN          13-302
# 7                    791        3752          341.1     NaN           7-162
# 8                    799        4752          396.0     NaN          13-290
# 9                    638        3470          315.5     NaN           7-235
# 10                   754        4581          416.5     NaN          13-289
# 11                   669        3743          340.3     NaN          22-563
# 12                   711        4360          396.4     NaN          11-285
# 13                   718        3884          353.1     NaN           5-118
# 14                   722        3940          358.2     NaN          12-285
# 15                   710        4119          374.5     NaN            5-97
# 16                   702        3622          301.8     NaN           8-195
# 17                   707        4018          365.3     NaN           7-145
# 18                   696        3915          355.9     NaN           6-112
# 19                   690        4841          440.1     NaN          11-268
# 20                   760        4369          364.1     NaN           7-176
# 21                   685        3374          306.7     NaN           9-206
# 22                   750        3978          361.6     NaN          16-343
# 23                   749        3470          289.2     NaN          12-249
# 24                   649        3201          291.0     NaN          14-302
# 25                   736        4163          378.5     NaN           5-103
# 26                   660        3410          310.0     NaN          17-376
# 27                   666        4374          397.6     NaN          11-237
# 28                   720        4110          342.5     NaN          18-471
# 29                   675        3482          316.5     NaN          14-281
# 30                   618        3376          306.9     NaN          13-264
# 31                   798        4500          375.0     NaN          17-455
#
#    Average Kickoff Return Yards Punt: Total Average Punt Return Yards  \
# 0                          18.0      21-207                      10.2
# 1                          17.5       16-88                      12.3
# 2                          19.1      22-276                      13.8
# 3                          21.7      21-186                      12.4
# 4                          29.8      25-231                       6.7
# 5                          21.4       11-79                      14.7
# 6                          23.2      21-272                       6.9
# 7                          23.1      30-247                      10.7
# 8                          22.3       16-92                       8.1
# 9                          33.6      10-188                       6.5
# 10                         22.2      16-168                       6.4
# 11                         25.6      19-175                      13.3
# 12                         25.9      18-143                       6.1
# 13                         23.6      19-179                      10.7
# 14                         23.8      16-171                       6.8
# 15                         19.4      28-214                      13.0
# 16                         24.4      15-162                       7.9
# 17                         20.7      16-261                       8.2
# 18                         18.7      20-150                      11.4
# 19                         24.4      19-173                       6.9
# 20                         25.1      24-197                       7.6
# 21                         22.9      20-129                       8.6
# 22                         21.4      18-259                       5.3
# 23                         20.8      23-149                       5.3
# 24                         21.6      17-170                      11.4
# 25                         20.6      20-295                       9.5
# 26                         22.1      20-138                       9.2
# 27                         21.5      23-194                      10.7
# 28                         26.2      21-235                       5.9
# 29                         20.1      16-147                      12.2
# 30                         20.3      27-214                      11.1
# 31                         26.8      28-207                       8.5
#
#    INT: Total Average Interception Yards Kicking Net Average Punt Yards  \
# 0        9-98                       10.9     NaN                   42.0
# 1       6-124                       20.7     NaN                   42.4
# 2      11-171                       15.5     NaN                   40.8
# 3       11-84                        7.6     NaN                   39.4
# 4       5-202                       40.4     NaN                   44.7
# 5      13-117                        9.0     NaN                   38.3
# 6      12-110                        9.2     NaN                   41.9
# 7        9-78                        8.7     NaN                   45.4
# 12      72-603                  54                NaN                   29:30
# 13      68-485                  44                NaN                   29:21
# 14      54-427                  38                NaN                   31:42
# 15      71-595                  54                NaN                   31:25
# 16      56-488                  40                NaN                   28:09
# 17      57-548                  49                NaN                   28:34
# 18      64-544                  49                NaN                   30:09
# 19      65-527                  47                NaN                   30:07
# 20      58-444                  37                NaN                   29:22
# 21      65-478                  43                NaN                   27:54
# 22      70-642                  58                NaN                   31:10
# 23      66-533                  44                NaN                   29:54
# 24      71-538                  48                NaN                   27:31
# 25      58-478                  43                NaN                   32:39
# 26      60-520                  47                NaN                   28:30
# 27      72-651                  59                NaN                   31:48
# 28      91-808                  67                NaN                   27:15
# 29      73-540                  49                NaN                   29:12
# 30      69-558                  50                NaN                   29:04
# 31      64-495                  41                NaN                   31:41
#
#    Miscellaneous Fumbles-Lost Turnover Ratio  Games
# 0            NaN         12-6             -1     17
# 1            NaN         11-9             -6     17
# 2            NaN         19-9              5     17
# 3            NaN         12-7              1     17
# 4            NaN         13-6             -7     17
# 5            NaN         18-9             -4     17
# 6            NaN          7-2             10     17
# 7            NaN        20-10             -7     17
# 8            NaN          9-3              8     17
# 9            NaN        14-10              8     17
# 10           NaN         13-9             -5     17
# 11           NaN         15-2              0     17
# 12           NaN         11-6              4     17
# 13           NaN         14-8              2     17
# 14           NaN        19-11              2     17
# 15           NaN         13-8             -5     17
# 16           NaN         10-4             -7     17
# 17           NaN         14-6              3     17
# 18           NaN          5-2             -3     17
# 19           NaN         20-8             -5     17
# 20           NaN        23-14             -8     17
# 21           NaN         11-5             -8     17
# 22           NaN         10-6              6     17
# 23           NaN         19-5              5     17
# 24           NaN        20-10             -1     17
# 25           NaN         12-6             -2     17
# 26           NaN          8-3             11     17
# 27           NaN         11-4             11     17
# 28           NaN          5-4              1     17
# 29           NaN         15-5              5     17
# 30           NaN          8-4             -4     17
# 31           NaN         16-9             -9     17

# %%
offNames = list('OFF_{}'.format(col) for col in offDF.columns)
# renaming all column headers in this dataframe to begin with off_. This is important for distinguishing between columns
# of the same name when we re-concatenate.

# %%
offDF.columns = offNames

# %%
offDF.head()
# Out:
#    OFF_index       OFF_SeasonID OFF_Total Points Per Game OFF_Total Points  \
# 0          0  Offense--ari-2023                      17.2              206
# 1          2  Offense--atl-2023                      19.4              213
# 2          4  Offense--bal-2023                      27.0              324
# 3          6  Offense--buf-2023                      27.3              328
# 4          8  Offense--car-2023                      15.7              173
#
#   OFF_Total Touchdowns OFF_1st Downs OFF_Total 1st downs  \
# 0                   22           NaN                 218
# 1                   21           NaN                 224
# 2                   37           NaN                 251
# 3                   39           NaN                 271
# 4                   17           NaN                 205
#
#   OFF_Rushing 1st downs OFF_Passing 1st downs OFF_1st downs by penalty  \
# 0                    76                   118                       24
# 1                    90                   119                       15
# 2                   108                   116                       27
# 3                   104                   149                       18
# 4                    67                   111                       27
#
#   OFF_3rd down efficiency OFF_3rd down % OFF_4th down efficiency  \
# 0                  54-153          35.29                    8-25
# 1                  62-148          41.89                    6-14
# 2                  66-152          43.42                    4-10
# 3                  77-155          49.68                    7-12
# 4                  60-161          37.27                   15-26
#
#   OFF_4th down % OFF_Passing OFF_Comp-Att OFF_Net Passing Yards  \
# 0          32.00         NaN      245-394                  2109
# 1          42.86         NaN      216-343                  2217
# 2          40.00         NaN      233-342                  2490
# 3          58.33         NaN      295-433                  3131
# 4          57.69         NaN      251-409                  1906
#
#   OFF_Yards Per Pass Attempt OFF_Net Passing Yards Per Game  \
# 0                        6.0                          175.8
# 1                        7.1                          201.5
# 2                        7.8                          207.5
# 3                        7.4                          260.9
# 4                        5.5                          173.3
#
#   OFF_Passing Touchdowns OFF_Interceptions OFF_Sacks-Yards Lost OFF_Rushing  \
# 0                     10                 9               33-241         NaN
# 1                     10                 9               30-211         NaN
# 2                     14                 5               29-166         NaN
# 3                     24                13                15-83         NaN
# 4                     11                 8               43-339         NaN
#
#   OFF_Rushing Attempts OFF_Rushing Yards OFF_Yards Per Rush Attempt  \
# 0                  305              1461                        4.8
# 1                  352              1532                        4.4
# 2                  390              1903                        4.9
# 3                  332              1468                        4.4
# 4                  267              1019                        3.8
#
#   OFF_Rushing Yards Per Game OFF_Rushing Touchdowns OFF_Offense  \
# 0                      121.8                     11         NaN
# 1                      139.3                     10         NaN
# 2                      158.6                     22         NaN
# 3                      122.3                     14         NaN
# 4                       92.6                      3         NaN
#
#   OFF_Total Offensive Plays OFF_Total Yards OFF_Yards Per Game OFF_Returns  \
# 0                       732            3811              317.6         NaN
# 1                       725            3960              360.0         NaN
# 2                       761            4559              379.9         NaN
# 3                       780            4682              390.2         NaN
# 4                       719            3264              296.7         NaN
#
#   OFF_Kickoffs: Total OFF_Average Kickoff Return Yards OFF_Punt: Total  \
# 0              10-180                             18.0          21-207
# 1              11-193                             17.5           16-88
# 2               8-153                             19.1          22-276
# 3              11-239                             21.7          21-186
# 4              15-447                             29.8          25-231
#
#   OFF_Average Punt Return Yards OFF_INT: Total OFF_Average Interception Yards  \
# 0                          10.2           9-98                           10.9
# 1                          12.3          6-124                           20.7
# 2                          13.8         11-171                           15.5
# 3                          12.4          11-84                            7.6
# 4                           6.7          5-202                           40.4
#
#   OFF_Kicking OFF_Net Average Punt Yards OFF_Punt: Total Yards  \
# 0         NaN                       42.0              48-2,343
# 1         NaN                       42.4              46-2,196
# 2         NaN                       40.8              47-2,260
# 3         NaN                       39.4              34-1,514
# 4         NaN                       44.7              52-2,456
#
#   OFF_FG: Good-Attempts OFF_Touchback Percentage OFF_Penalties  \
# 0                 19-22                       84           NaN
# 1                 22-23                       85           NaN
# 2                 21-26                       84           NaN
# 3                 18-23                       57           NaN
# 4                 18-21                       59           NaN
#
#   OFF_Total-Yards OFF_Avg. Per Game (YDS) OFF_Time of Possession  \
# 0          79-720                      60                    NaN
# 1          59-528                      48                    NaN
# 2          73-684                      57                    NaN
# 3          84-696                      58                    NaN
# 4          74-590                      53                    NaN
#
#   OFF_Possession Time Seconds OFF_Miscellaneous OFF_Fumbles-Lost  \
# 0                       27:46               NaN             12-6
# 1                       30:17               NaN             11-9
# 2                       31:49               NaN             19-9
# 3                       31:20               NaN             12-7
# 4                       30:54               NaN             13-6
#
#   OFF_Turnover Ratio  OFF_Games
# 0                 -1         17
# 1                 -6         17
# 2                  5         17
# 3                  1         17
# 4                 -7         17

# %%
defDF.reset_index(inplace=True)
defDF.drop(columns='index')
# do it again for the defense
# Out:
#                      SeasonID Total Points Per Game Total Points  \
# 0   Opposing-offense-ari-2023                  26.8          321
# 1   Opposing-offense-atl-2023                  21.1          232
# 2   Opposing-offense-bal-2023                  15.6          187
# 3   Opposing-offense-buf-2023                  18.9          227
# 4   Opposing-offense-car-2023                  26.5          292
# 5   Opposing-offense-chi-2023                  24.7          296
# 6   Opposing-offense-cin-2023                  22.0          242
# 7   Opposing-offense-cle-2023                  19.0          209
# 8   Opposing-offense-dal-2023                  18.3          220
# 9   Opposing-offense-den-2023                  25.5          280
# 10  Opposing-offense-det-2023                  23.5          258
# 11   Opposing-offense-gb-2023                  20.4          224
# 12  Opposing-offense-hou-2023                  21.1          232
# 13  Opposing-offense-ind-2023                  24.4          268
# 14  Opposing-offense-jax-2023                  20.5          225
# 15   Opposing-offense-kc-2023                  16.5          181
# 16   Opposing-offense-lv-2023                  21.3          256
# 17  Opposing-offense-lac-2023                  23.5          258
# 18  Opposing-offense-lar-2023                  21.3          234
# 19  Opposing-offense-mia-2023                  22.8          251
# 20  Opposing-offense-min-2023                  20.2          242
# 21   Opposing-offense-ne-2023                  22.5          248
# 22   Opposing-offense-no-2023                  20.2          222
# 23  Opposing-offense-nyg-2023                  24.3          292
# 24  Opposing-offense-nyj-2023                  21.6          238
# 25  Opposing-offense-phi-2023                  22.4          246
# 26  Opposing-offense-pit-2023                  18.6          205
# 27   Opposing-offense-sf-2023                  15.5          170
# 28  Opposing-offense-sea-2023                  24.2          290
# 29   Opposing-offense-tb-2023                  20.6          227
# 30  Opposing-offense-ten-2023                  20.4          224
# 31  Opposing-offense-wsh-2023                  29.2          350
#
#    Total Touchdowns 1st Downs Total 1st downs Rushing 1st downs  \
# 0                38       NaN             270               101
# 1                22       NaN             204                61
# 2                16       NaN             209                66
# 3                25       NaN             228                65
# 4                35       NaN             215                84
# 5                34       NaN             225                58
# 6                25       NaN             241                88
# 7                25       NaN             142                55
# 8                27       NaN             211                68
# 9                31       NaN             238                84
# 10               30       NaN             216                56
# 11               23       NaN             223                85
# 12               24       NaN             224                73
# 13               28       NaN             224                86
# 14               27       NaN             198                58
# 15               21       NaN             191                66
# 16               28       NaN             244                88
# 17               30       NaN             248                69
# 18               23       NaN             217                72
# 19               30       NaN             208                72
# 20               23       NaN             223                73
# 21               26       NaN             204                60
# 22               23       NaN             204                71
# 23               35       NaN             244                93
# 24               22       NaN             213                80
# 25               29       NaN             232                56
# 26               19       NaN             213                64
# 27               17       NaN             203                64
# 28               32       NaN             266                86
# 29               23       NaN             227                66
# 30               20       NaN             213                68
# 31               39       NaN             236                71
#
#    Passing 1st downs 1st downs by penalty 3rd down efficiency 3rd down %  \
# 21                    3.4                   94.1                  9     NaN
# 22                    4.5                  124.0                  7     NaN
# 23                    4.8                  136.1                 18     NaN
# 24                    4.2                  140.3                  7     NaN
# 25                    4.1                   85.3                  5     NaN
# 26                    4.3                  118.4                  6     NaN
# 27                    4.0                   82.0                  5     NaN
# 28                    4.2                  119.3                 15     NaN
# 29                    3.9                   95.9                  7     NaN
# 30                    3.8                  110.8                  8     NaN
# 31                    4.4                  113.1                  7     NaN
#
#    Total Offensive Plays Total Yards Yards Per Game Returns Kickoffs: Total  \
# 0                    781        4535          377.9     NaN            3-63
# 1                    687        3681          334.6     NaN           7-153
# 2                    779        3661          305.1     NaN          10-220
# 3                    730        4074          339.5     NaN          23-470
# 4                    666        3476          316.0     NaN          13-322
# 5                    726        3927          327.3     NaN           9-226
# 6                    696        4451          404.6     NaN           7-120
# 7                    601        2964          269.5     NaN          15-272
# 8                    717        3682          306.8     NaN            3-93
# 9                    704        4444          404.0     NaN            3-53
# 10                   659        3701          336.5     NaN          18-369
# 11                   724        3901          354.6     NaN          22-504
# 12                   701        3995          363.2     NaN          20-442
# 13                   751        4117          374.3     NaN          10-256
# 14                   682        3924          356.7     NaN          10-269
# 15                   655        3402          309.3     NaN            3-75
# 16                   769        4279          356.6     NaN          17-367
# 17                   744        4557          414.3     NaN           7-146
# 18                   697        3818          347.1     NaN           7-212
# 19                   687        3611          328.3     NaN          11-332
# 20                   767        4075          339.6     NaN          14-340
# 21                   707        3638          330.7     NaN          12-281
# 22                   681        3637          330.6     NaN           6-127
# 23                   767        4533          377.8     NaN           9-244
# 24                   740        3728          338.9     NaN            5-82
# 25                   718        3965          360.5     NaN          11-327
# 26                   724        4095          372.3     NaN          13-346
# 27                   674        3473          315.7     NaN          25-583
# 28                   821        4479          373.3     NaN          15-334
# 29                   704        4207          382.5     NaN          15-277
# 30                   701        3899          354.5     NaN          19-415
# 31                   763        4687          390.6     NaN             0-0
#
#    Average Kickoff Return Yards Punt: Total Average Punt Return Yards  \
# 0                          21.0      32-325                       9.9
# 1                          21.9      20-245                       5.5
# 2                          22.0      22-304                      12.5
# 3                          20.4      14-173                       8.9
# 4                          24.8      20-134                       9.2
# 5                          25.1      21-309                       7.2
# 6                          17.1      20-138                      13.0
# 7                          18.1      26-277                       8.2
# 8                          31.0      16-130                       5.8
# 9                          17.7      21-136                      18.8
# 10                         20.5       10-64                      10.5
# 11                         22.9      19-253                       9.2
# 12                         22.1       14-86                       7.9
# 13                         25.6      24-256                       9.4
# 14                         26.9       14-95                      10.7
# 15                         25.0      13-169                       7.6
# 16                         21.6      17-135                      10.8
# 17                         20.9      15-123                      16.3
# 18                         30.3      19-216                       7.5
# 19                         30.2        9-62                       9.1
# 20                         24.3      15-114                       8.2
# 21                         23.4      25-216                       6.5
# 22                         21.2      19-101                      14.4
# 23                         27.1      29-154                       6.5
# 24                         16.4      31-352                      10.0
# 25                         29.7      21-199                      14.8
# 26                         26.6      22-202                       6.9
# 27                         23.3      15-161                       8.4
#    Total-Yards Avg. Per Game (YDS) Time of Possession Possession Time Seconds  \
# 0       73-599              49.917                NaN                   32:13
# 1       73-600              54.545                NaN                   29:42
# 2       76-596              49.667                NaN                   28:54
# 3       75-582                48.5                NaN                   29:20
# 4       67-491              44.636                NaN                   29:05
# 5       51-395              32.917                NaN                   28:16
# 6       60-552              50.182                NaN                   30:26
# 7       77-659              59.909                NaN                   26:41
# 8       78-717               59.75                NaN                   27:56
# 9       81-747              67.909                NaN                   31:04
# 10      56-488              44.364                NaN                   28:16
# 11      66-634              57.636                NaN                   31:21
# 12      70-611              55.545                NaN                   30:29
# 13      56-470              42.727                NaN                   31:49
# 14      74-700              63.636                NaN                   28:17
# 15      49-416              37.818                NaN                   28:34
# 16      71-629              52.417                NaN                   31:50
# 17      76-561                  51                NaN                   31:52
# 18      73-630              57.273                NaN                   30:13
# 19      58-450              40.909                NaN                   29:52
# 20      87-749              62.417                NaN                   30:37
# 21      61-442              40.182                NaN                   32:05
# 22      71-533              48.455                NaN                   28:49
# 23      75-622              51.833                NaN                   30:25
# 24      58-496              45.091                NaN                   32:55
# 25      79-609              55.364                NaN                   28:34
# 26      65-550                  50                NaN                   31:29
# 27      65-533              48.455                NaN                   28:11
# 28      76-620              51.667                NaN                   33:06
# 29      70-588              53.455                NaN                   30:47
# 30      66-526              47.818                NaN                   31:22
# 31      73-586              48.833                NaN                   28:48
#
#    Miscellaneous Fumbles-Lost Turnover Ratio  Games
# 0            NaN          7-5            161     17
# 1            NaN         12-6            140     17
# 2            NaN         14-8            133     17
# 3            NaN        19-10            161     17
# 4            NaN          5-2            151     17
# 5            NaN         13-4            145     17
# 6            NaN         12-7            135     17
# 7            NaN         13-7            140     17
# 8            NaN         13-5            139     17
# 9            NaN        25-12            128     17
# 10           NaN          9-4            119     17
# 11           NaN          9-7            131     17
# 12           NaN         15-7            151     17
# 13           NaN         17-6            124     17
# 14           NaN         15-9            129     17
# 15           NaN         17-8            149     17
# 16           NaN          8-4            182     17
# 17           NaN         17-9            141     17
# 18           NaN          9-4            141     17
# 19           NaN          9-5            142     17
# 20           NaN         18-7            155     17
# 21           NaN         12-5            158     17
# 22           NaN          9-6            127     17
# 23           NaN         15-7            140     17
# 24           NaN         20-7            142     17
# 25           NaN         17-8            137     17
# 26           NaN         19-8            129     17
# 27           NaN         10-6            151     17
# 28           NaN         13-7            152     17
# 29           NaN         13-8            157     17
# 30           NaN         11-5            175     17
# 31           NaN         12-7            132     17

# %%
defNames = list('DEF_{}'.format(col) for col in defDF.columns)

# %%
defDF.columns = defNames

# %%
defDF.head()
# Out:
#    DEF_index               DEF_SeasonID DEF_Total Points Per Game  \
# 0          1  Opposing-offense-ari-2023                      26.8
# 1          3  Opposing-offense-atl-2023                      21.1
# 2          5  Opposing-offense-bal-2023                      15.6
# 3          7  Opposing-offense-buf-2023                      18.9
# 4          9  Opposing-offense-car-2023                      26.5
#
#   DEF_Total Points DEF_Total Touchdowns DEF_1st Downs DEF_Total 1st downs  \
# 0              321                   38           NaN                 270
# 1              232                   22           NaN                 204
# 2              187                   16           NaN                 209
# 3              227                   25           NaN                 228
# 4              292                   35           NaN                 215
#
#   DEF_Rushing 1st downs DEF_Passing 1st downs DEF_1st downs by penalty  \
# 0                   101                   146                       23
# 1                    61                   120                       23
# 2                    66                   117                       26
# 3                    65                   136                       27
# 4                    84                   112                       19
#
#   DEF_3rd down efficiency DEF_3rd down % DEF_4th down efficiency  \
# 0                  71-151          47.02                    6-13
# 1                  50-142          35.21                    5-10
# 2                  64-177          36.16                    8-22
# 3                  60-156          38.46                    9-16
# 4                  48-137          35.04                     6-8
#
#   DEF_4th down % DEF_Passing DEF_Comp-Att DEF_Net Passing Yards  \
# 0          46.15         NaN      261-372                  2621
# 1          50.00         NaN      227-361                  2300
# 2          36.36         NaN      270-446                  2060
# 3          56.25         NaN      261-389                  2439
# 4          75.00         NaN      211-322                  1976
#
#   DEF_Yards Per Pass Attempt DEF_Net Passing Yards Per Game  \
# 0                        7.7                          218.4
# 1                        6.8                          209.1
# 2                        5.5                          171.7
# 3                        6.9                          203.3
# 4                        6.5                          179.6
#
#   DEF_Passing Touchdowns DEF_Interceptions DEF_Sacks-Yards Lost DEF_Rushing  \
# 0                     21                 9               32-233         NaN
# 1                     17                 6               22-149         NaN
# 2                     10                11               47-374         NaN
# 3                     16                11               41-235         NaN
# 4                     13                 5               18-126         NaN
#
#   DEF_Rushing Attempts DEF_Rushing Yards DEF_Yards Per Rush Attempt  \
# 0                  377              1681                        4.5
# 1                  304              1232                        4.1
# 2                  286              1227                        4.3
# 3                  300              1400                        4.7
# 4                  326              1374                        4.2
#
#   DEF_Rushing Yards Per Game DEF_Rushing Touchdowns DEF_Offense  \
# 0                      140.1                     16         NaN
# 1                      112.0                      4         NaN
# 2                      102.3                      4         NaN
# 3                      116.7                      8         NaN
# 4                      124.9                     18         NaN
#
#   DEF_Total Offensive Plays DEF_Total Yards DEF_Yards Per Game DEF_Returns  \
# 0                       781            4535              377.9         NaN
# 1                       687            3681              334.6         NaN
# 2                       779            3661              305.1         NaN
# 3                       730            4074              339.5         NaN
# 4                       666            3476              316.0         NaN
#
#   DEF_Kickoffs: Total DEF_Average Kickoff Return Yards DEF_Punt: Total  \
# 0                3-63                             21.0          32-325
# 1               7-153                             21.9          20-245
# 2              10-220                             22.0          22-304
# 3              23-470                             20.4          14-173
# 4              13-322                             24.8          20-134
#
#   DEF_Average Punt Return Yards DEF_INT: Total DEF_Average Interception Yards  \
# 0                           9.9           9-41                            4.6
# 1                           5.5          9-139                           15.4
# 2                          12.5           5-54                           10.8
# 3                           8.9          13-71                            5.5
# 4                           9.2          8-165                           20.6
#
#   DEF_Kicking DEF_Net Average Punt Yards DEF_Punt: Total Yards  \
# 0         NaN                       43.2              42-2,020
# 1         NaN                       45.9              48-2,292
# 2         NaN                       41.6              58-2,687
# 3         NaN                       45.2              49-2,401
# 4         NaN                       44.5              51-2,498
#
#   DEF_FG: Good-Attempts DEF_Touchback Percentage DEF_Penalties  \
# 0                 19-23                       82           NaN
# 1                 26-27                       81           NaN
# 2                 25-26                       67           NaN
# 3                 19-20                       72           NaN
# 4                 16-16                       75           NaN
#
#   DEF_Total-Yards DEF_Avg. Per Game (YDS) DEF_Time of Possession  \
# 0          73-599                  49.917                    NaN
# 1          73-600                  54.545                    NaN
# 2          76-596                  49.667                    NaN
# 3          75-582                    48.5                    NaN
# 4          67-491                  44.636                    NaN
#
#   DEF_Possession Time Seconds DEF_Miscellaneous DEF_Fumbles-Lost  \
# 0                       32:13               NaN              7-5
# 1                       29:42               NaN             12-6
# 2                       28:54               NaN             14-8
# 3                       29:20               NaN            19-10
# 4                       29:05               NaN              5-2
#
#   DEF_Turnover Ratio  DEF_Games
# 0                161         17
# 1                140         17
# 2                133         17
# 3                161         17
# 4                151         17

# %%
defDF.shape
# Out:
# (32, 53)

# %%
offDF.shape
# Out:
# (32, 53)

# %%
final_df = pd.merge(offDF, defDF, left_index=True, right_index=True)

# %%
final_df.head()
# Out:
#    OFF_index       OFF_SeasonID OFF_Total Points Per Game OFF_Total Points  \
# 0          0  Offense--ari-2023                      17.2              206
# 1          2  Offense--atl-2023                      19.4              213
# 2          4  Offense--bal-2023                      27.0              324
# 3          6  Offense--buf-2023                      27.3              328
# 4          8  Offense--car-2023                      15.7              173
#
#   OFF_Total Touchdowns OFF_1st Downs OFF_Total 1st downs  \
# 0                   22           NaN                 218
# 1                   21           NaN                 224
# 2                   37           NaN                 251
# 3                   39           NaN                 271
# 4                   17           NaN                 205
#
#   OFF_Rushing 1st downs OFF_Passing 1st downs OFF_1st downs by penalty  \
# 0                    76                   118                       24
# 1                    90                   119                       15
# 2                   108                   116                       27
# 3                   104                   149                       18
# 4                    67                   111                       27
#
#   OFF_3rd down efficiency OFF_3rd down % OFF_4th down efficiency  \
# 0                  54-153          35.29                    8-25
# 1                  62-148          41.89                    6-14
# 2                  66-152          43.42                    4-10
# 3                  77-155          49.68                    7-12
# 4                  60-161          37.27                   15-26
#
#   OFF_4th down % OFF_Passing OFF_Comp-Att OFF_Net Passing Yards  \
# 0          32.00         NaN      245-394                  2109
# 1          42.86         NaN      216-343                  2217
# 2          40.00         NaN      233-342                  2490
# 3          58.33         NaN      295-433                  3131
# 4          57.69         NaN      251-409                  1906
#
#   OFF_Yards Per Pass Attempt OFF_Net Passing Yards Per Game  \
# 0                        6.0                          175.8
# 1                        7.1                          201.5
# 2                        7.8                          207.5
# 3                        7.4                          260.9
# 4                        5.5                          173.3
#
#   OFF_Passing Touchdowns OFF_Interceptions OFF_Sacks-Yards Lost OFF_Rushing  \
# 0                     10                 9               33-241         NaN
# 1                     10                 9               30-211         NaN
# 2                     14                 5               29-166         NaN
# 3                     24                13                15-83         NaN
# 4                     11                 8               43-339         NaN
#
#   OFF_Rushing Attempts OFF_Rushing Yards OFF_Yards Per Rush Attempt  \
# 0                  305              1461                        4.8
# 1                  352              1532                        4.4
# 2                  390              1903                        4.9
# 3                  332              1468                        4.4
# 4                  267              1019                        3.8
#
#   OFF_Rushing Yards Per Game OFF_Rushing Touchdowns OFF_Offense  \
# 0                      121.8                     11         NaN
# 1                      139.3                     10         NaN
# 2                      158.6                     22         NaN
# 3                      122.3                     14         NaN
# 4                       92.6                      3         NaN
#
#   OFF_Total Offensive Plays OFF_Total Yards OFF_Yards Per Game OFF_Returns  \
# 0                       732            3811              317.6         NaN
# 1                       725            3960              360.0         NaN
# 2                       761            4559              379.9         NaN
# 3                       780            4682              390.2         NaN
# 4                       719            3264              296.7         NaN
#
#   OFF_Kickoffs: Total OFF_Average Kickoff Return Yards OFF_Punt: Total  \
# 0              10-180                             18.0          21-207
# 1              11-193                             17.5           16-88
# 2               8-153                             19.1          22-276
# 3              11-239                             21.7          21-186
# 4              15-447                             29.8          25-231
#
#   OFF_Average Punt Return Yards OFF_INT: Total OFF_Average Interception Yards  \
# 0                          10.2           9-98                           10.9
# 1                          12.3          6-124                           20.7
# 2                          13.8         11-171                           15.5
# 3                          12.4          11-84                            7.6
# 4                           6.7          5-202                           40.4
#
#   OFF_Kicking OFF_Net Average Punt Yards OFF_Punt: Total Yards  \
# 0         NaN                       42.0              48-2,343
# 1         NaN                       42.4              46-2,196
# 2         NaN                       40.8              47-2,260
# 3         NaN                       39.4              34-1,514
# 4         NaN                       44.7              52-2,456
#
#   OFF_FG: Good-Attempts OFF_Touchback Percentage OFF_Penalties  \
# 0                 19-22                       84           NaN
# 1                 22-23                       85           NaN
# 2                 21-26                       84           NaN
# 3                 18-23                       57           NaN
# 4                 18-21                       59           NaN
#
#   OFF_Total-Yards OFF_Avg. Per Game (YDS) OFF_Time of Possession  \
# 0          79-720                      60                    NaN
# 1          59-528                      48                    NaN
# 2          73-684                      57                    NaN
# 3          84-696                      58                    NaN
# 4          74-590                      53                    NaN
#
#   OFF_Possession Time Seconds OFF_Miscellaneous OFF_Fumbles-Lost  \
# 0                       27:46               NaN             12-6
# 1                       30:17               NaN             11-9
# 2                       31:49               NaN             19-9
# 3                       31:20               NaN             12-7
# 4                       30:54               NaN             13-6
#
#   OFF_Turnover Ratio  OFF_Games  DEF_index               DEF_SeasonID  \
# 0                 -1         17          1  Opposing-offense-ari-2023
# 1                 -6         17          3  Opposing-offense-atl-2023
# 2                  5         17          5  Opposing-offense-bal-2023
# 3                  1         17          7  Opposing-offense-buf-2023
# 4                 -7         17          9  Opposing-offense-car-2023
#
#   DEF_Total Points Per Game DEF_Total Points DEF_Total Touchdowns  \
# 0                      26.8              321                   38
# 1                      21.1              232                   22
# 2                      15.6              187                   16
# 3                      18.9              227                   25
# 4                      26.5              292                   35
#
#   DEF_1st Downs DEF_Total 1st downs DEF_Rushing 1st downs  \
# 0           NaN                 270                   101
# 1           NaN                 204                    61
# 2           NaN                 209                    66
# 3           NaN                 228                    65
# 4           NaN                 215                    84
#
#   DEF_Passing 1st downs DEF_1st downs by penalty DEF_3rd down efficiency  \
# 0                   146                       23                  71-151
# 1                   120                       23                  50-142
# 2                   117                       26                  64-177
# 3                   136                       27                  60-156
# 4                   112                       19                  48-137
#
#   DEF_3rd down % DEF_4th down efficiency DEF_4th down % DEF_Passing  \
# 0          47.02                    6-13          46.15         NaN
# 1          35.21                    5-10          50.00         NaN
# 2          36.16                    8-22          36.36         NaN
# 3          38.46                    9-16          56.25         NaN
# 4          35.04                     6-8          75.00         NaN
#
#   DEF_Comp-Att DEF_Net Passing Yards DEF_Yards Per Pass Attempt  \
# 0      261-372                  2621                        7.7
# 1      227-361                  2300                        6.8
# 2      270-446                  2060                        5.5
# 3      261-389                  2439                        6.9
# 4      211-322                  1976                        6.5
#
#   DEF_Net Passing Yards Per Game DEF_Passing Touchdowns DEF_Interceptions  \
# 0                          218.4                     21                 9
# 1                          209.1                     17                 6
# 2                          171.7                     10                11
# 3                          203.3                     16                11
# 4                          179.6                     13                 5
#
#   DEF_Sacks-Yards Lost DEF_Rushing DEF_Rushing Attempts DEF_Rushing Yards  \
# 0               32-233         NaN                  377              1681
# 1               22-149         NaN                  304              1232
# 2               47-374         NaN                  286              1227
# 3               41-235         NaN                  300              1400
# 4               18-126         NaN                  326              1374
#
#   DEF_Yards Per Rush Attempt DEF_Rushing Yards Per Game  \
# 0                        4.5                      140.1
# 1                        4.1                      112.0
# 2                        4.3                      102.3
# 3                        4.7                      116.7
# 4                        4.2                      124.9
#
#   DEF_Rushing Touchdowns DEF_Offense DEF_Total Offensive Plays  \
# 0                     16         NaN                       781
# 1                      4         NaN                       687
# 2                      4         NaN                       779
# 3                      8         NaN                       730
# 4                     18         NaN                       666
#
#   DEF_Total Yards DEF_Yards Per Game DEF_Returns DEF_Kickoffs: Total  \
# 0            4535              377.9         NaN                3-63
# 1            3681              334.6         NaN               7-153
# 2            3661              305.1         NaN              10-220
# 3            4074              339.5         NaN              23-470
# 4            3476              316.0         NaN              13-322
#
#   DEF_Average Kickoff Return Yards DEF_Punt: Total  \
# 0                             21.0          32-325
# 1                             21.9          20-245
# 2                             22.0          22-304
# 3                             20.4          14-173
# 4                             24.8          20-134
#
#   DEF_Average Punt Return Yards DEF_INT: Total DEF_Average Interception Yards  \
# 0                           9.9           9-41                            4.6
# 1                           5.5          9-139                           15.4
# 2                          12.5           5-54                           10.8
# 3                           8.9          13-71                            5.5
# 4                           9.2          8-165                           20.6
#
#   DEF_Kicking DEF_Net Average Punt Yards DEF_Punt: Total Yards  \
# 0         NaN                       43.2              42-2,020
# 1         NaN                       45.9              48-2,292
# 2         NaN                       41.6              58-2,687
# 3         NaN                       45.2              49-2,401
# 4         NaN                       44.5              51-2,498
#
#   DEF_FG: Good-Attempts DEF_Touchback Percentage DEF_Penalties  \
# 0                 19-23                       82           NaN
# 1                 26-27                       81           NaN
# 2                 25-26                       67           NaN
# 3                 19-20                       72           NaN
# 4                 16-16                       75           NaN
#
#   DEF_Total-Yards DEF_Avg. Per Game (YDS) DEF_Time of Possession  \
# 0          73-599                  49.917                    NaN
# 1          73-600                  54.545                    NaN
# 2          76-596                  49.667                    NaN
# 3          75-582                    48.5                    NaN
# 4          67-491                  44.636                    NaN
#
#   DEF_Possession Time Seconds DEF_Miscellaneous DEF_Fumbles-Lost  \
# 0                       32:13               NaN              7-5
# 1                       29:42               NaN             12-6
# 2                       28:54               NaN             14-8
# 3                       29:20               NaN            19-10
# 4                       29:05               NaN              5-2
#
#   DEF_Turnover Ratio  DEF_Games
# 0                161         17
# 1                140         17
# 2                133         17
# 3                161         17
# 4                151         17

# %%
final_df.shape
# Out:
# (32, 106)

# %%
final_df.duplicated().sum()
# thank god
# Out:
# 0

# %%
final_df.columns
# Out:
# Index(['OFF_index', 'OFF_SeasonID', 'OFF_Total Points Per Game',
#        'OFF_Total Points', 'OFF_Total Touchdowns', 'OFF_1st Downs',
#        'OFF_Total 1st downs', 'OFF_Rushing 1st downs', 'OFF_Passing 1st downs',
#        'OFF_1st downs by penalty',
#        ...
#        'DEF_Touchback Percentage', 'DEF_Penalties', 'DEF_Total-Yards',
#        'DEF_Avg. Per Game (YDS)', 'DEF_Time of Possession',
#        'DEF_Possession Time Seconds', 'DEF_Miscellaneous', 'DEF_Fumbles-Lost',
#        'DEF_Turnover Ratio', 'DEF_Games'],
#       dtype='object', length=106)

# %%
pd.set_option('display.max_rows',None)
final_df.isna().sum()
# this is also good. 1st downs, passing, rushing, offense, returns and all other columns with nulls are headers
# on the original dataset. They describe the columns that follow, and are therefore unnecessary. They can be dropped.
# Out:
# OFF_index                            0
# OFF_SeasonID                         0
# OFF_Total Points Per Game            0
# OFF_Total Points                     0
# OFF_Total Touchdowns                 0
# OFF_1st Downs                       32
# OFF_Total 1st downs                  0
# OFF_Rushing 1st downs                0
# OFF_Passing 1st downs                0
# OFF_1st downs by penalty             0
# OFF_3rd down efficiency              0
# OFF_3rd down %                       0
# OFF_4th down efficiency              0
# OFF_4th down %                       0
# OFF_Passing                         32
# OFF_Comp-Att                         0
# OFF_Net Passing Yards                0
# OFF_Yards Per Pass Attempt           0
# OFF_Net Passing Yards Per Game       0
# OFF_Passing Touchdowns               0
# OFF_Interceptions                    0
# OFF_Sacks-Yards Lost                 0
# OFF_Rushing                         32
# OFF_Rushing Attempts                 0
# OFF_Rushing Yards                    0
# OFF_Yards Per Rush Attempt           0
# OFF_Rushing Yards Per Game           0
# OFF_Rushing Touchdowns               0
# OFF_Offense                         32
# OFF_Total Offensive Plays            0
# OFF_Total Yards                      0
# OFF_Yards Per Game                   0
# OFF_Returns                         32
# OFF_Kickoffs: Total                  0
# OFF_Average Kickoff Return Yards     0
# OFF_Punt: Total                      0
# OFF_Average Punt Return Yards        0
# OFF_INT: Total                       0
# OFF_Average Interception Yards       0
# OFF_Kicking                         32
# OFF_Net Average Punt Yards           0
# OFF_Punt: Total Yards                0
# OFF_FG: Good-Attempts                0
# OFF_Touchback Percentage             0
# OFF_Penalties                       32
# OFF_Total-Yards                      0
# OFF_Avg. Per Game (YDS)              0
# OFF_Time of Possession              32
# OFF_Possession Time Seconds          0
# OFF_Miscellaneous                   32
# OFF_Fumbles-Lost                     0
# OFF_Turnover Ratio                   0
# OFF_Games                            0
# DEF_index                            0
# DEF_SeasonID                         0
# DEF_Total Points Per Game            0
# DEF_Total Points                     0
# DEF_Total Touchdowns                 0
# DEF_1st Downs                       32
# DEF_Total 1st downs                  0
# DEF_Rushing 1st downs                0
# DEF_Passing 1st downs                0
# DEF_1st downs by penalty             0
# DEF_3rd down efficiency              0
# DEF_3rd down %                       0
# DEF_4th down efficiency              0
# DEF_4th down %                       0
# DEF_Passing                         32
# DEF_Comp-Att                         0
# DEF_Net Passing Yards                0
# DEF_Yards Per Pass Attempt           0
# DEF_Net Passing Yards Per Game       0
# DEF_Passing Touchdowns               0
# DEF_Interceptions                    0
# DEF_Sacks-Yards Lost                 0
# DEF_Rushing                         32
# DEF_Rushing Attempts                 0
# DEF_Rushing Yards                    0
# DEF_Yards Per Rush Attempt           0
# DEF_Rushing Yards Per Game           0
# DEF_Rushing Touchdowns               0
# DEF_Offense                         32
# DEF_Total Offensive Plays            0
# DEF_Total Yards                      0
# DEF_Yards Per Game                   0
# DEF_Returns                         32
# DEF_Kickoffs: Total                  0
# DEF_Average Kickoff Return Yards     0
# DEF_Punt: Total                      0
# DEF_Average Punt Return Yards        0
# DEF_INT: Total                       0
# DEF_Average Interception Yards       0
# DEF_Kicking                         32
# DEF_Net Average Punt Yards           0
# DEF_Punt: Total Yards                0
# DEF_FG: Good-Attempts                0
# DEF_Touchback Percentage             0
# DEF_Penalties                       32
# DEF_Total-Yards                      0
# DEF_Avg. Per Game (YDS)              0
# DEF_Time of Possession              32
# DEF_Possession Time Seconds          0
# DEF_Miscellaneous                   32
# DEF_Fumbles-Lost                     0
# DEF_Turnover Ratio                   0
# DEF_Games                            0
# dtype: int64

# %%
# We'll start by dropping the header columns (columns used to classify the columns that follow them on ESPN). 
final_df = final_df.drop(columns=['OFF_1st Downs', 'OFF_Passing', 'OFF_Offense', 'OFF_Returns', 'OFF_Kicking', 'OFF_Penalties', 'OFF_Time of Possession', 'OFF_Miscellaneous'])

# %%
final_df.head()
# check to make sure it worked
# Out:
#    OFF_index       OFF_SeasonID OFF_Total Points Per Game OFF_Total Points  \
# 0          0  Offense--ari-2023                      17.2              206
# 1          2  Offense--atl-2023                      19.4              213
# 2          4  Offense--bal-2023                      27.0              324
# 3          6  Offense--buf-2023                      27.3              328
# 4          8  Offense--car-2023                      15.7              173
#
#   OFF_Total Touchdowns OFF_Total 1st downs OFF_Rushing 1st downs  \
# 0                   22                 218                    76
# 1                   21                 224                    90
# 2                   37                 251                   108
# 3                   39                 271                   104
# 4                   17                 205                    67
#
#   OFF_Passing 1st downs OFF_1st downs by penalty OFF_3rd down efficiency  \
# 0                   118                       24                  54-153
# 1                   119                       15                  62-148
# 2                   116                       27                  66-152
# 3                   149                       18                  77-155
# 4                   111                       27                  60-161
#
#   OFF_3rd down % OFF_4th down efficiency OFF_4th down % OFF_Comp-Att  \
# 0          35.29                    8-25          32.00      245-394
# 1          41.89                    6-14          42.86      216-343
# 2          43.42                    4-10          40.00      233-342
# 3          49.68                    7-12          58.33      295-433
# 4          37.27                   15-26          57.69      251-409
#
#   OFF_Net Passing Yards OFF_Yards Per Pass Attempt  \
# 0                  2109                        6.0
# 1                  2217                        7.1
# 2                  2490                        7.8
# 3                  3131                        7.4
# 4                  1906                        5.5
#
#   OFF_Net Passing Yards Per Game OFF_Passing Touchdowns OFF_Interceptions  \
# 0                          175.8                     10                 9
# 1                          201.5                     10                 9
# 2                          207.5                     14                 5
# 3                          260.9                     24                13
# 4                          173.3                     11                 8
#
#   OFF_Sacks-Yards Lost OFF_Rushing OFF_Rushing Attempts OFF_Rushing Yards  \
# 0               33-241         NaN                  305              1461
# 1               30-211         NaN                  352              1532
# 2               29-166         NaN                  390              1903
# 3                15-83         NaN                  332              1468
# 4               43-339         NaN                  267              1019
#
#   OFF_Yards Per Rush Attempt OFF_Rushing Yards Per Game  \
# 0                        4.8                      121.8
# 1                        4.4                      139.3
# 2                        4.9                      158.6
# 3                        4.4                      122.3
# 4                        3.8                       92.6
#
#   OFF_Rushing Touchdowns OFF_Total Offensive Plays OFF_Total Yards  \
# 0                     11                       732            3811
# 1                     10                       725            3960
# 2                     22                       761            4559
# 3                     14                       780            4682
# 4                      3                       719            3264
#
#   OFF_Yards Per Game OFF_Kickoffs: Total OFF_Average Kickoff Return Yards  \
# 0              317.6              10-180                             18.0
# 1              360.0              11-193                             17.5
# 2              379.9               8-153                             19.1
# 3              390.2              11-239                             21.7
# 4              296.7              15-447                             29.8
#
#   OFF_Punt: Total OFF_Average Punt Return Yards OFF_INT: Total  \
# 0          21-207                          10.2           9-98
# 1           16-88                          12.3          6-124
# 2          22-276                          13.8         11-171
# 3          21-186                          12.4          11-84
# 4          25-231                           6.7          5-202
#
#   OFF_Average Interception Yards OFF_Net Average Punt Yards  \
# 0                           10.9                       42.0
# 1                           20.7                       42.4
# 2                           15.5                       40.8
# 3                            7.6                       39.4
# 4                           40.4                       44.7
#
#   OFF_Punt: Total Yards OFF_FG: Good-Attempts OFF_Touchback Percentage  \
# 0              48-2,343                 19-22                       84
# 1              46-2,196                 22-23                       85
# 2              47-2,260                 21-26                       84
# 3              34-1,514                 18-23                       57
# 4              52-2,456                 18-21                       59
#
#   OFF_Total-Yards OFF_Avg. Per Game (YDS) OFF_Possession Time Seconds  \
# 0          79-720                      60                       27:46
# 1          59-528                      48                       30:17
# 2          73-684                      57                       31:49
# 3          84-696                      58                       31:20
# 4          74-590                      53                       30:54
#
#   OFF_Fumbles-Lost OFF_Turnover Ratio  OFF_Games  DEF_index  \
# 0             12-6                 -1         17          1
# 1             11-9                 -6         17          3
# 2             19-9                  5         17          5
# 3             12-7                  1         17          7
# 4             13-6                 -7         17          9
#
#                 DEF_SeasonID DEF_Total Points Per Game DEF_Total Points  \
# 0  Opposing-offense-ari-2023                      26.8              321
# 1  Opposing-offense-atl-2023                      21.1              232
# 2  Opposing-offense-bal-2023                      15.6              187
# 3  Opposing-offense-buf-2023                      18.9              227
# 4  Opposing-offense-car-2023                      26.5              292
#
#   DEF_Total Touchdowns DEF_1st Downs DEF_Total 1st downs  \
# 0                   38           NaN                 270
# 1                   22           NaN                 204
# 2                   16           NaN                 209
# 3                   25           NaN                 228
# 4                   35           NaN                 215
#
#   DEF_Rushing 1st downs DEF_Passing 1st downs DEF_1st downs by penalty  \
# 0                   101                   146                       23
# 1                    61                   120                       23
# 2                    66                   117                       26
# 3                    65                   136                       27
# 4                    84                   112                       19
#
#   DEF_3rd down efficiency DEF_3rd down % DEF_4th down efficiency  \
# 0                  71-151          47.02                    6-13
# 1                  50-142          35.21                    5-10
# 2                  64-177          36.16                    8-22
# 3                  60-156          38.46                    9-16
# 4                  48-137          35.04                     6-8
#
#   DEF_4th down % DEF_Passing DEF_Comp-Att DEF_Net Passing Yards  \
# 0          46.15         NaN      261-372                  2621
# 1          50.00         NaN      227-361                  2300
# 2          36.36         NaN      270-446                  2060
# 3          56.25         NaN      261-389                  2439
# 4          75.00         NaN      211-322                  1976
#
#   DEF_Yards Per Pass Attempt DEF_Net Passing Yards Per Game  \
# 0                        7.7                          218.4
# 1                        6.8                          209.1
# 2                        5.5                          171.7
# 3                        6.9                          203.3
# 4                        6.5                          179.6
#
#   DEF_Passing Touchdowns DEF_Interceptions DEF_Sacks-Yards Lost DEF_Rushing  \
# 0                     21                 9               32-233         NaN
# 1                     17                 6               22-149         NaN
# 2                     10                11               47-374         NaN
# 3                     16                11               41-235         NaN
# 4                     13                 5               18-126         NaN
#
#   DEF_Rushing Attempts DEF_Rushing Yards DEF_Yards Per Rush Attempt  \
# 0                  377              1681                        4.5
# 1                  304              1232                        4.1
# 2                  286              1227                        4.3
# 3                  300              1400                        4.7
# 4                  326              1374                        4.2
#
#   DEF_Rushing Yards Per Game DEF_Rushing Touchdowns DEF_Offense  \
# 0                      140.1                     16         NaN
# 1                      112.0                      4         NaN
# 2                      102.3                      4         NaN
# 3                      116.7                      8         NaN
# 4                      124.9                     18         NaN
#
#   DEF_Total Offensive Plays DEF_Total Yards DEF_Yards Per Game DEF_Returns  \
# 0                       781            4535              377.9         NaN
# 1                       687            3681              334.6         NaN
# 2                       779            3661              305.1         NaN
# 3                       730            4074              339.5         NaN
# 4                       666            3476              316.0         NaN
#
#   DEF_Kickoffs: Total DEF_Average Kickoff Return Yards DEF_Punt: Total  \
# 0                3-63                             21.0          32-325
# 1               7-153                             21.9          20-245
# 2              10-220                             22.0          22-304
# 3              23-470                             20.4          14-173
# 4              13-322                             24.8          20-134
#
#   DEF_Average Punt Return Yards DEF_INT: Total DEF_Average Interception Yards  \
# 0                           9.9           9-41                            4.6
# 1                           5.5          9-139                           15.4
# 2                          12.5           5-54                           10.8
# 3                           8.9          13-71                            5.5
# 4                           9.2          8-165                           20.6
#
#   DEF_Kicking DEF_Net Average Punt Yards DEF_Punt: Total Yards  \
# 0         NaN                       43.2              42-2,020
# 1         NaN                       45.9              48-2,292
# 2         NaN                       41.6              58-2,687
# 3         NaN                       45.2              49-2,401
# 4         NaN                       44.5              51-2,498
#
#   DEF_FG: Good-Attempts DEF_Touchback Percentage DEF_Penalties  \
# 0                 19-23                       82           NaN
# 1                 26-27                       81           NaN
# 2                 25-26                       67           NaN
# 3                 19-20                       72           NaN
# 4                 16-16                       75           NaN
#
#   DEF_Total-Yards DEF_Avg. Per Game (YDS) DEF_Time of Possession  \
# 0          73-599                  49.917                    NaN
# 1          73-600                  54.545                    NaN
# 2          76-596                  49.667                    NaN
# 3          75-582                    48.5                    NaN
# 4          67-491                  44.636                    NaN
#
#   DEF_Possession Time Seconds DEF_Miscellaneous DEF_Fumbles-Lost  \
# 0                       32:13               NaN              7-5
# 1                       29:42               NaN             12-6
# 2                       28:54               NaN             14-8
# 3                       29:20               NaN            19-10
# 4                       29:05               NaN              5-2
#
#   DEF_Turnover Ratio  DEF_Games
# 0                161         17
# 1                140         17
# 2                133         17
# 3                161         17
# 4                151         17

# %%
final_df = final_df.drop(columns=['DEF_1st Downs', 'DEF_Passing', 'DEF_Offense', 'DEF_Returns', 'DEF_Kicking', 'DEF_Penalties', 'DEF_Time of Possession', 'DEF_Miscellaneous'])
# same rows as before but defense

# %%
final_df = final_df.drop(columns=['OFF_Rushing', 'DEF_Rushing', 'DEF_SeasonID'])
# forgot rushing for both so dropping those. Drop year because its redundant, and def_season ID because we can 
# identify defensive stats by their new column name

# %%
final_df.head()
# Out:
#    OFF_index       OFF_SeasonID OFF_Total Points Per Game OFF_Total Points  \
# 0          0  Offense--ari-2023                      17.2              206
# 1          2  Offense--atl-2023                      19.4              213
# 2          4  Offense--bal-2023                      27.0              324
# 3          6  Offense--buf-2023                      27.3              328
# 4          8  Offense--car-2023                      15.7              173
#
#   OFF_Total Touchdowns OFF_Total 1st downs OFF_Rushing 1st downs  \
# 0                   22                 218                    76
# 1                   21                 224                    90
# 2                   37                 251                   108
# 3                   39                 271                   104
# 4                   17                 205                    67
#
#   OFF_Passing 1st downs OFF_1st downs by penalty OFF_3rd down efficiency  \
# 0                   118                       24                  54-153
# 1                   119                       15                  62-148
# 2                   116                       27                  66-152
# 3                   149                       18                  77-155
# 4                   111                       27                  60-161
#
#   OFF_3rd down % OFF_4th down efficiency OFF_4th down % OFF_Comp-Att  \
# 0          35.29                    8-25          32.00      245-394
# 1          41.89                    6-14          42.86      216-343
# 2          43.42                    4-10          40.00      233-342
# 3          49.68                    7-12          58.33      295-433
# 4          37.27                   15-26          57.69      251-409
#
#   OFF_Net Passing Yards OFF_Yards Per Pass Attempt  \
# 0                  2109                        6.0
# 1                  2217                        7.1
# 2                  2490                        7.8
# 3                  3131                        7.4
# 4                  1906                        5.5
#
#   OFF_Net Passing Yards Per Game OFF_Passing Touchdowns OFF_Interceptions  \
# 0                          175.8                     10                 9
# 1                          201.5                     10                 9
# 2                          207.5                     14                 5
# 3                          260.9                     24                13
# 4                          173.3                     11                 8
#
#   OFF_Sacks-Yards Lost OFF_Rushing Attempts OFF_Rushing Yards  \
# 0               33-241                  305              1461
# 1               30-211                  352              1532
# 2               29-166                  390              1903
# 3                15-83                  332              1468
# 4               43-339                  267              1019
#
#   OFF_Yards Per Rush Attempt OFF_Rushing Yards Per Game  \
# 0                        4.8                      121.8
# 1                        4.4                      139.3
# 2                        4.9                      158.6
# 3                        4.4                      122.3
# 4                        3.8                       92.6
#
#   OFF_Rushing Touchdowns OFF_Total Offensive Plays OFF_Total Yards  \
# 0                     11                       732            3811
# 1                     10                       725            3960
# 2                     22                       761            4559
# 3                     14                       780            4682
# 4                      3                       719            3264
#
#   OFF_Yards Per Game OFF_Kickoffs: Total OFF_Average Kickoff Return Yards  \
# 0              317.6              10-180                             18.0
# 1              360.0              11-193                             17.5
# 2              379.9               8-153                             19.1
# 3              390.2              11-239                             21.7
# 4              296.7              15-447                             29.8
#
#   OFF_Punt: Total OFF_Average Punt Return Yards OFF_INT: Total  \
# 0          21-207                          10.2           9-98
# 1           16-88                          12.3          6-124
# 2          22-276                          13.8         11-171
# 3          21-186                          12.4          11-84
# 4          25-231                           6.7          5-202
#
#   OFF_Average Interception Yards OFF_Net Average Punt Yards  \
# 0                           10.9                       42.0
# 1                           20.7                       42.4
# 2                           15.5                       40.8
# 3                            7.6                       39.4
# 4                           40.4                       44.7
#
#   OFF_Punt: Total Yards OFF_FG: Good-Attempts OFF_Touchback Percentage  \
# 0              48-2,343                 19-22                       84
# 1              46-2,196                 22-23                       85
# 2              47-2,260                 21-26                       84
# 3              34-1,514                 18-23                       57
# 4              52-2,456                 18-21                       59
#
#   OFF_Total-Yards OFF_Avg. Per Game (YDS) OFF_Possession Time Seconds  \
# 0          79-720                      60                       27:46
# 1          59-528                      48                       30:17
# 2          73-684                      57                       31:49
# 3          84-696                      58                       31:20
# 4          74-590                      53                       30:54
#
#   OFF_Fumbles-Lost OFF_Turnover Ratio  OFF_Games  DEF_index  \
# 0             12-6                 -1         17          1
# 1             11-9                 -6         17          3
# 2             19-9                  5         17          5
# 3             12-7                  1         17          7
# 4             13-6                 -7         17          9
#
#   DEF_Total Points Per Game DEF_Total Points DEF_Total Touchdowns  \
# 0                      26.8              321                   38
# 1                      21.1              232                   22
# 2                      15.6              187                   16
# 3                      18.9              227                   25
# 4                      26.5              292                   35
#
#   DEF_Total 1st downs DEF_Rushing 1st downs DEF_Passing 1st downs  \
# 0                 270                   101                   146
# 1                 204                    61                   120
# 2                 209                    66                   117
# 3                 228                    65                   136
# 4                 215                    84                   112
#
#   DEF_1st downs by penalty DEF_3rd down efficiency DEF_3rd down %  \
# 0                       23                  71-151          47.02
# 1                       23                  50-142          35.21
# 2                       26                  64-177          36.16
# 3                       27                  60-156          38.46
# 4                       19                  48-137          35.04
#
#   DEF_4th down efficiency DEF_4th down % DEF_Comp-Att DEF_Net Passing Yards  \
# 0                    6-13          46.15      261-372                  2621
# 1                    5-10          50.00      227-361                  2300
# 2                    8-22          36.36      270-446                  2060
# 3                    9-16          56.25      261-389                  2439
# 4                     6-8          75.00      211-322                  1976
#
#   DEF_Yards Per Pass Attempt DEF_Net Passing Yards Per Game  \
# 0                        7.7                          218.4
# 1                        6.8                          209.1
# 2                        5.5                          171.7
# 3                        6.9                          203.3
# 4                        6.5                          179.6
#
#   DEF_Passing Touchdowns DEF_Interceptions DEF_Sacks-Yards Lost  \
# 0                     21                 9               32-233
# 1                     17                 6               22-149
# 2                     10                11               47-374
# 3                     16                11               41-235
# 4                     13                 5               18-126
#
#   DEF_Rushing Attempts DEF_Rushing Yards DEF_Yards Per Rush Attempt  \
# 0                  377              1681                        4.5
# 1                  304              1232                        4.1
# 2                  286              1227                        4.3
# 3                  300              1400                        4.7
# 4                  326              1374                        4.2
#
#   DEF_Rushing Yards Per Game DEF_Rushing Touchdowns DEF_Total Offensive Plays  \
# 0                      140.1                     16                       781
# 1                      112.0                      4                       687
# 2                      102.3                      4                       779
# 3                      116.7                      8                       730
# 4                      124.9                     18                       666
#
#   DEF_Total Yards DEF_Yards Per Game DEF_Kickoffs: Total  \
# 0            4535              377.9                3-63
# 1            3681              334.6               7-153
# 2            3661              305.1              10-220
# 3            4074              339.5              23-470
# 4            3476              316.0              13-322
#
#   DEF_Average Kickoff Return Yards DEF_Punt: Total  \
# 0                             21.0          32-325
# 1                             21.9          20-245
# 2                             22.0          22-304
# 3                             20.4          14-173
# 4                             24.8          20-134
#
#   DEF_Average Punt Return Yards DEF_INT: Total DEF_Average Interception Yards  \
# 0                           9.9           9-41                            4.6
# 1                           5.5          9-139                           15.4
# 2                          12.5           5-54                           10.8
# 3                           8.9          13-71                            5.5
# 4                           9.2          8-165                           20.6
#
#   DEF_Net Average Punt Yards DEF_Punt: Total Yards DEF_FG: Good-Attempts  \
# 0                       43.2              42-2,020                 19-23
# 1                       45.9              48-2,292                 26-27
# 2                       41.6              58-2,687                 25-26
# 3                       45.2              49-2,401                 19-20
# 4                       44.5              51-2,498                 16-16
#
#   DEF_Touchback Percentage DEF_Total-Yards DEF_Avg. Per Game (YDS)  \
# 0                       82          73-599                  49.917
# 1                       81          73-600                  54.545
# 2                       67          76-596                  49.667
# 3                       72          75-582                    48.5
# 4                       75          67-491                  44.636
#
#   DEF_Possession Time Seconds DEF_Fumbles-Lost DEF_Turnover Ratio  DEF_Games
# 0                       32:13              7-5                161         17
# 1                       29:42             12-6                140         17
# 2                       28:54             14-8                133         17
# 3                       29:20            19-10                161         17
# 4                       29:05              5-2                151         17

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 87 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   OFF_index                         32 non-null     int64
#  1   OFF_SeasonID                      32 non-null     object
#  2   OFF_Total Points Per Game         32 non-null     object
#  3   OFF_Total Points                  32 non-null     object
#  4   OFF_Total Touchdowns              32 non-null     object
#  5   OFF_Total 1st downs               32 non-null     object
#  6   OFF_Rushing 1st downs             32 non-null     object
#  7   OFF_Passing 1st downs             32 non-null     object
#  8   OFF_1st downs by penalty          32 non-null     object
#  9   OFF_3rd down efficiency           32 non-null     object
#  10  OFF_3rd down %                    32 non-null     object
#  11  OFF_4th down efficiency           32 non-null     object
#  12  OFF_4th down %                    32 non-null     object
#  13  OFF_Comp-Att                      32 non-null     object
#  14  OFF_Net Passing Yards             32 non-null     object
#  15  OFF_Yards Per Pass Attempt        32 non-null     object
#  16  OFF_Net Passing Yards Per Game    32 non-null     object
#  17  OFF_Passing Touchdowns            32 non-null     object
#  18  OFF_Interceptions                 32 non-null     object
#  19  OFF_Sacks-Yards Lost              32 non-null     object
#  20  OFF_Rushing Attempts              32 non-null     object
#  21  OFF_Rushing Yards                 32 non-null     object
#  22  OFF_Yards Per Rush Attempt        32 non-null     object
#  23  OFF_Rushing Yards Per Game        32 non-null     object
#  24  OFF_Rushing Touchdowns            32 non-null     object
#  25  OFF_Total Offensive Plays         32 non-null     object
#  26  OFF_Total Yards                   32 non-null     object
#  27  OFF_Yards Per Game                32 non-null     object
#  28  OFF_Kickoffs: Total               32 non-null     object
#  29  OFF_Average Kickoff Return Yards  32 non-null     object
#  30  OFF_Punt: Total                   32 non-null     object
#  31  OFF_Average Punt Return Yards     32 non-null     object
#  32  OFF_INT: Total                    32 non-null     object
#  33  OFF_Average Interception Yards    32 non-null     object
#  34  OFF_Net Average Punt Yards        32 non-null     object
#  35  OFF_Punt: Total Yards             32 non-null     object
#  36  OFF_FG: Good-Attempts             32 non-null     object
#  37  OFF_Touchback Percentage          32 non-null     object
#  38  OFF_Total-Yards                   32 non-null     object
#  39  OFF_Avg. Per Game (YDS)           32 non-null     object
#  40  OFF_Possession Time Seconds       32 non-null     object
#  41  OFF_Fumbles-Lost                  32 non-null     object
#  42  OFF_Turnover Ratio                32 non-null     object
#  43  OFF_Games                         32 non-null     int64
#  44  DEF_index                         32 non-null     int64
#  45  DEF_Total Points Per Game         32 non-null     object
#  46  DEF_Total Points                  32 non-null     object
#  47  DEF_Total Touchdowns              32 non-null     object
#  48  DEF_Total 1st downs               32 non-null     object
#  49  DEF_Rushing 1st downs             32 non-null     object
#  50  DEF_Passing 1st downs             32 non-null     object
#  51  DEF_1st downs by penalty          32 non-null     object
#  52  DEF_3rd down efficiency           32 non-null     object
#  53  DEF_3rd down %                    32 non-null     object
#  54  DEF_4th down efficiency           32 non-null     object
#  55  DEF_4th down %                    32 non-null     object
#  56  DEF_Comp-Att                      32 non-null     object
#  57  DEF_Net Passing Yards             32 non-null     object
#  58  DEF_Yards Per Pass Attempt        32 non-null     object
#  59  DEF_Net Passing Yards Per Game    32 non-null     object
#  60  DEF_Passing Touchdowns            32 non-null     object
#  61  DEF_Interceptions                 32 non-null     object
#  62  DEF_Sacks-Yards Lost              32 non-null     object
#  63  DEF_Rushing Attempts              32 non-null     object
#  64  DEF_Rushing Yards                 32 non-null     object
#  65  DEF_Yards Per Rush Attempt        32 non-null     object
#  66  DEF_Rushing Yards Per Game        32 non-null     object
#  67  DEF_Rushing Touchdowns            32 non-null     object
#  68  DEF_Total Offensive Plays         32 non-null     object
#  69  DEF_Total Yards                   32 non-null     object
#  70  DEF_Yards Per Game                32 non-null     object
#  71  DEF_Kickoffs: Total               32 non-null     object
#  72  DEF_Average Kickoff Return Yards  32 non-null     object
#  73  DEF_Punt: Total                   32 non-null     object
#  74  DEF_Average Punt Return Yards     32 non-null     object
#  75  DEF_INT: Total                    32 non-null     object
#  76  DEF_Average Interception Yards    32 non-null     object
#  77  DEF_Net Average Punt Yards        32 non-null     object
#  78  DEF_Punt: Total Yards             32 non-null     object
#  79  DEF_FG: Good-Attempts             32 non-null     object
#  80  DEF_Touchback Percentage          32 non-null     object
#  81  DEF_Total-Yards                   32 non-null     object
#  82  DEF_Avg. Per Game (YDS)           32 non-null     object
#  83  DEF_Possession Time Seconds       32 non-null     object
#  84  DEF_Fumbles-Lost                  32 non-null     object
#  85  DEF_Turnover Ratio                32 non-null     object
#  86  DEF_Games                         32 non-null     int64
# dtypes: int64(4), object(83)
# memory usage: 21.9+ KB

# %%
final_df.to_csv('In-Season_Wk13.csv', index=False)
# You are going to want to change the name you export to, or it will override the previous week's data. I am naming 
# them for weeks so I can understand what I'm looking at in my folder.

# Name of week 11 includes all data played UP TO AND DURING WEEK 11. This is used to make predictions on Week 12

# %% [markdown]
# ## Feature Engineering Steps

# %%
fun = pd.read_csv('/Users/justintunley/Documents/BrainStation/Capstone/In-Season_2023_Week11.csv')
# I felt like it was a fitting name....

# %%
fun.head()
# Out:
#             SeasonID   PPG  Tot_TDs_PG  1st_Downs_PG  Rush_1st_Downs_PG  \
# 0  Offense--ari-2023  17.5    1.176471     11.705882           4.176471
# 1  Offense--atl-2023  18.9    1.058824     11.705882           4.411765
# 2  Offense--bal-2023  27.6    2.058824     13.588235           5.764706
# 3  Offense--buf-2023  26.7    2.058824     14.235294           5.352941
# 4  Offense--car-2023  16.3    0.941176     10.941176           3.470588
#
#    Pass_1st_Downs_PG  OFF_1st_by_pen_PG  3rd_Conv_Rate  4th_Conv_Rate  \
# 0           6.294118           1.235294          35.29          27.27
# 1           6.470588           0.823529          41.43          46.15
# 2           6.294118           1.529412          44.60          42.86
# 3           7.882353           1.000000          48.12          54.55
# 4           6.117647           1.352941          37.24          56.52
#
#    Pass_Comp_Rate  Pass_Yds_PG  Pass_Yds_Per_Attempt  Pass_Tds_PG  Off_Int_PG  \
# 0        0.624642   111.176471                   6.0     0.529412    0.529412
# 1        0.630435   120.529412                   7.0     0.529412    0.411765
# 2        0.693548   136.823529                   8.0     0.764706    0.294118
# 3        0.696335   164.647059                   7.5     1.294118    0.705882
# 4        0.616402   102.588235                   5.4     0.647059    0.470588
#
#    Rush_Att_PG  Yds_Per_Rush  Rush_Yds_PG  Rush_Tds_PG  Off_Plays_PG  \
# 0    17.058824           4.8        126.2     0.588235     39.294118
# 1    18.294118           4.2        130.4     0.529412     39.000000
# 2    20.882353           4.8        155.1     1.235294     40.705882
# 3    17.176471           4.4        117.7     0.705882     40.470588
# 4    13.823529           3.9         92.3     0.117647     38.352941
#
#    Tot_Yds_PG  Kickoffs_Returned_PG  Avg_K_Return_Yds  Punts_Returned_PG  \
# 0       316.5              0.588235              18.0           1.235294
# 1       356.4              0.529412              16.7           0.882353
# 2       380.5              0.470588              19.1           1.235294
# 3       379.1              0.588235              21.4           0.941176
# 4       297.4              0.705882              31.3           1.352941
#
#    Avg_P_Return_Yds  Int_Forced_PG  Avg_I_Return_Yds  Yds_Per_Punt  Punts_PG  \
# 0              10.1       0.470588              10.5          42.1  2.529412
# 1              12.6       0.294118               6.4          42.4  2.588235
# 2              13.4       0.588235              17.1          41.3  2.588235
# 3              11.9       0.588235               8.2          39.6  1.764706
# 4               6.6       0.294118              40.4          44.7  2.705882
#
#    FG_Conv_Rate  Touchback_Rate  Penalties_PG  Avg_Pen_Yds_PG   Avg_TOP  \
# 0      0.904762            0.85      4.352941              62  0.466833
# 1      0.954545            0.83      3.176471              49  0.504833
# 2      0.826087            0.85      4.000000              58  0.523333
# 3      0.842105            0.58      4.294118              56  0.505000
# 4      0.850000            0.63      4.117647              55  0.506000
#
#    Fum_Lost_PG  Games  DEF_PPG_Against  DEF_Tot_Tds_PG_Against  \
# 0     0.352941     17             25.8                1.941176
# 1     0.529412     17             21.7                1.294118
# 2     0.529412     17             16.1                0.882353
# 3     0.411765     17             17.3                1.176471
# 4     0.294118     17             27.5                1.941176
#
#    DEF_1st_Downs_PG_Against  DEF_Rush_1st_Downs_PG_Against  \
# 0                 14.411765                       5.411765
# 1                 10.705882                       3.235294
# 2                 11.352941                       3.588235
# 3                 12.000000                       3.294118
# 4                 11.764706                       4.588235
#
#    DEF_Pass_1st_Downs_PG_Against  DEF_1st_by_pen_PG  DEF_3rd_Conv_Rate  \
# 0                       7.647059           1.352941              46.76
# 1                       6.294118           1.176471              34.38
# 2                       6.235294           1.529412              35.19
# 3                       7.294118           1.411765              38.62
# 4                       6.058824           1.117647              36.51
#
#    DEF_4th_Conv_Rate  DEF_Pass_Comp_Rate  DEF_Pass_Yds_Per_Attempt  \
# 0              36.36            0.696165                       7.7
# 1              50.00            0.628483                       6.6
# 2              36.84            0.599502                       5.5
# 3              56.25            0.678771                       6.9
# 4              71.43            0.656463                       6.5
#
#    DEF_Pass_Yds_PG  DEF_Pass_Tds_PG  DEF_Int_PG  DEF_Rush_Att_PG  \
# 0            217.5         1.000000    0.470588        20.235294
# 1            200.4         1.000000    0.294118        16.235294
# 2            169.7         0.529412    0.588235        15.705882
# 3            204.2         0.764706    0.588235        15.764706
# 4            179.2         0.764706    0.294118        17.764706
#
#    DEF_Yds_Per_Rush  DEF_Rush_Yds_PG  DEF_Rush_Tds_PG  DEF_Tot_Plays_PG  \
# 0               4.2            132.1         0.882353         42.058824
# 1               3.9            108.4         0.235294         36.470588
# 2               4.3            103.7         0.235294         41.941176
# 3               4.5            110.5         0.352941         39.117647
# 4               4.3            129.4         0.941176         36.058824
#
#    DEF_YPG_Against  DEF_Kickoffs_Returned_PG  DEF_Avg_K_Return_Yds  \
# 0            370.7                  0.176471                  21.0
# 1            322.9                  0.411765                  21.9
# 2            305.3                  0.529412                  22.1
# 3            335.4                  1.352941                  20.4
# 4            321.1                  0.588235                  24.7
#
#    DEF_Punts_Returned_PG  DEF_Avg_P_Return_Yds  DEF_Avg_I_Return_Yds  \
# 0               1.764706                   9.9                   4.6
# 1               1.117647                   5.3                  16.9
# 2               1.235294                  13.0                  10.8
# 3               0.764706                   9.3                   5.5
# 4               1.058824                   9.7                  20.6
#
#    DEF_Yds_Per_Punt_Against  DEF_Punts_PG  DEF_FG_Conv_Rate  \
# 0                      43.5      2.352941          0.857143
# 1                      46.1      2.764706          1.000000
# 2                      41.1      3.235294          0.960000
# 3                      45.1      2.588235          0.947368
# 4                      43.2      2.588235          1.000000
#
#    DEF_Touchback_Rate  DEF_Penalties_PG  DEF_Avg_Pen_Yds_PG  DEF_Avg_TOP  \
# 0                0.80          4.000000              52.364     0.526333
# 1                0.83          3.941176              55.000     0.488333
# 2                0.65          4.176471              50.455     0.484500
# 3                0.70          4.176471              50.182     0.489000
# 4                0.79          3.470588              43.800     0.487167
#
#    DEF_Fum_Lost_PG  Sacks_Taken_PG  Sack_Yds_Lost_PG  FG_Att_PG  FG_Good_PG  \
# 0         0.294118        1.705882         12.000000   1.235294    1.117647
# 1         0.294118        1.764706         12.411765   1.294118    1.235294
# 2         0.294118        1.588235          9.000000   1.352941    1.117647
# 3         0.529412        0.823529          4.470588   1.117647    0.941176
# 4         0.117647        2.294118         18.058824   1.176471    1.000000
#
#    Pass_Att_PG  DEF_Pass_Att_PG  DEF_Sacks_PG  DEF_Sack_Yds_PG  DEF_FG_Att_PG  \
# 0    20.529412        19.941176      1.882353        13.705882       1.235294
# 1    18.941176        19.000000      1.235294         8.294118       1.235294
# 2    18.235294        23.647059      2.588235        20.588235       1.470588
# 3    22.470588        21.058824      2.294118        13.411765       1.117647
# 4    22.235294        17.294118      1.000000         7.352941       0.882353
#
#    DEF_FG_Good_PG
# 0        1.058824
# 1        1.235294
# 2        1.411765
# 3        1.058824
# 4        0.882353

# %%
fun.shape
# Out:
# (32, 77)

# %%
fun = fun.replace(',','', regex=True)

# %%
fun.rename(columns={'OFF_SeasonID':'SeasonID'}, inplace=True)

# %%
fun.rename(columns={'OFF_Games': 'Games'}, inplace=True)

# %%
fun.head()
# Out:
#             SeasonID   PPG  Tot_TDs_PG  1st_Downs_PG  Rush_1st_Downs_PG  \
# 0  Offense--ari-2023  17.5    1.176471     11.705882           4.176471
# 1  Offense--atl-2023  18.9    1.058824     11.705882           4.411765
# 2  Offense--bal-2023  27.6    2.058824     13.588235           5.764706
# 3  Offense--buf-2023  26.7    2.058824     14.235294           5.352941
# 4  Offense--car-2023  16.3    0.941176     10.941176           3.470588
#
#    Pass_1st_Downs_PG  OFF_1st_by_pen_PG  3rd_Conv_Rate  4th_Conv_Rate  \
# 0           6.294118           1.235294          35.29          27.27
# 1           6.470588           0.823529          41.43          46.15
# 2           6.294118           1.529412          44.60          42.86
# 3           7.882353           1.000000          48.12          54.55
# 4           6.117647           1.352941          37.24          56.52
#
#    Pass_Comp_Rate  Pass_Yds_PG  Pass_Yds_Per_Attempt  Pass_Tds_PG  Off_Int_PG  \
# 0        0.624642   111.176471                   6.0     0.529412    0.529412
# 1        0.630435   120.529412                   7.0     0.529412    0.411765
# 3            204.2         0.764706    0.588235        15.764706
# 4            179.2         0.764706    0.294118        17.764706
#
#    DEF_Yds_Per_Rush  DEF_Rush_Yds_PG  DEF_Rush_Tds_PG  DEF_Tot_Plays_PG  \
# 0               4.2            132.1         0.882353         42.058824
# 1               3.9            108.4         0.235294         36.470588
# 2               4.3            103.7         0.235294         41.941176
# 3               4.5            110.5         0.352941         39.117647
# 4               4.3            129.4         0.941176         36.058824
#
#    DEF_YPG_Against  DEF_Kickoffs_Returned_PG  DEF_Avg_K_Return_Yds  \
# 0            370.7                  0.176471                  21.0
# 1            322.9                  0.411765                  21.9
# 2            305.3                  0.529412                  22.1
# 3            335.4                  1.352941                  20.4
# 4            321.1                  0.588235                  24.7
#
#    DEF_Punts_Returned_PG  DEF_Avg_P_Return_Yds  DEF_Avg_I_Return_Yds  \
# 0               1.764706                   9.9                   4.6
# 1               1.117647                   5.3                  16.9
# 2               1.235294                  13.0                  10.8
# 3               0.764706                   9.3                   5.5
# 4               1.058824                   9.7                  20.6
#
#    DEF_Yds_Per_Punt_Against  DEF_Punts_PG  DEF_FG_Conv_Rate  \
# 0                      43.5      2.352941          0.857143
# 1                      46.1      2.764706          1.000000
# 2                      41.1      3.235294          0.960000
# 3                      45.1      2.588235          0.947368
# 4                      43.2      2.588235          1.000000
#
#    DEF_Touchback_Rate  DEF_Penalties_PG  DEF_Avg_Pen_Yds_PG  DEF_Avg_TOP  \
# 0                0.80          4.000000              52.364     0.526333
# 1                0.83          3.941176              55.000     0.488333
# 2                0.65          4.176471              50.455     0.484500
# 3                0.70          4.176471              50.182     0.489000
# 4                0.79          3.470588              43.800     0.487167
#
#    DEF_Fum_Lost_PG  Sacks_Taken_PG  Sack_Yds_Lost_PG  FG_Att_PG  FG_Good_PG  \
# 0         0.294118        1.705882         12.000000   1.235294    1.117647
# 1         0.294118        1.764706         12.411765   1.294118    1.235294
# 2         0.294118        1.588235          9.000000   1.352941    1.117647
# 3         0.529412        0.823529          4.470588   1.117647    0.941176
# 4         0.117647        2.294118         18.058824   1.176471    1.000000
#
#    Pass_Att_PG  DEF_Pass_Att_PG  DEF_Sacks_PG  DEF_Sack_Yds_PG  DEF_FG_Att_PG  \
# 0    20.529412        19.941176      1.882353        13.705882       1.235294
# 1    18.941176        19.000000      1.235294         8.294118       1.235294
# 2    18.235294        23.647059      2.588235        20.588235       1.470588
# 3    22.470588        21.058824      2.294118        13.411765       1.117647
# 4    22.235294        17.294118      1.000000         7.352941       0.882353
#
#    DEF_FG_Good_PG
# 0        1.058824
# 1        1.235294
# 2        1.411765
# 3        1.058824
# 4        0.882353

# %%
# Here we will be going feature by feature doing 1 of 4 things:
#     1. If it is a rate of calculation on a per-game basis, we leave as is
#     2. If it is a season total that is not already calculated, we divide by the games column
#     3. If is a header or unnecessary, we drop
#     4. In some cases, we can split info into two new columns to get more valuable information
# For all of them, we will rename the header

# %%
# Note: We can do a lot of these together in single steps, but for ease of understanding we went one-by-one

# %%
# Note to self: remember our target variables will be PPG and PA_PG

# %%
fun.rename(columns={'OFF_Total Points Per Game':'PPG'}, inplace=True)

# %%
fun = fun.drop(columns=['OFF_Total Points'])
# this is the same as PPG but multiplied by number of games. Therefore redundant and can drop
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1
# 0     0.352941     17             25.8                1.941176
# 1     0.529412     17             21.7                1.294118
# 2     0.529412     17             16.1                0.882353
# 3     0.411765     17             17.3                1.176471
# 4     0.294118     17             27.5                1.941176
#
#    DEF_1st_Downs_PG_Against  DEF_Rush_1st_Downs_PG_Against  \
# 0                 14.411765                       5.411765
# 1                 10.705882                       3.235294
# 2                 11.352941                       3.588235
# 3                 12.000000                       3.294118
# 4                 11.764706                       4.588235
#
#    DEF_Pass_1st_Downs_PG_Against  DEF_1st_by_pen_PG  DEF_3rd_Conv_Rate  \
# 0                       7.647059           1.352941              46.76
# 1                       6.294118           1.176471              34.38
# 2                       6.235294           1.529412              35.19
# 3                       7.294118           1.411765              38.62
# 4                       6.058824           1.117647              36.51
#
#    DEF_4th_Conv_Rate  DEF_Pass_Comp_Rate  DEF_Pass_Yds_Per_Attempt  \
# 0              36.36            0.696165                       7.7
# 1              50.00            0.628483                       6.6
# 2              36.84            0.599502                       5.5
# 3              56.25            0.678771                       6.9
# 4              71.43            0.656463                       6.5
#
#    DEF_Pass_Yds_PG  DEF_Pass_Tds_PG  DEF_Int_PG  DEF_Rush_Att_PG  \
# 0            217.5         1.000000    0.470588        20.235294
# 1            200.4         1.000000    0.294118        16.235294
# 2            169.7         0.529412    0.588235        15.705882
# 3            204.2         0.764706    0.588235        15.764706
# 4            179.2         0.764706    0.294118        17.764706
#
#    DEF_Yds_Per_Rush  DEF_Rush_Yds_PG  DEF_Rush_Tds_PG  DEF_Tot_Plays_PG  \
# 0               4.2            132.1         0.882353         42.058824
# 1               3.9            108.4         0.235294         36.470588
# 2               4.3            103.7         0.235294         41.941176
# 3               4.5            110.5         0.352941         39.117647
# 4               4.3            129.4         0.941176         36.058824
#
#    DEF_YPG_Against  DEF_Kickoffs_Returned_PG  DEF_Avg_K_Return_Yds  \
# 0            370.7                  0.176471                  21.0
# 1            322.9                  0.411765                  21.9
# 2            305.3                  0.529412                  22.1
# 3            335.4                  1.352941                  20.4
# 4            321.1                  0.588235                  24.7
#
#    DEF_Punts_Returned_PG  DEF_Avg_P_Return_Yds  DEF_Avg_I_Return_Yds  \
# 0               1.764706                   9.9                   4.6
# 1               1.117647                   5.3                  16.9
# 2               1.235294                  13.0                  10.8
# 3               0.764706                   9.3                   5.5
# 4               1.058824                   9.7                  20.6
#
#    DEF_Yds_Per_Punt_Against  DEF_Punts_PG  DEF_FG_Conv_Rate  \
# 0                      43.5      2.352941          0.857143
# 1                      46.1      2.764706          1.000000
# 2                      41.1      3.235294          0.960000
# 3                      45.1      2.588235          0.947368
# 4                      43.2      2.588235          1.000000
#
#    DEF_Touchback_Rate  DEF_Penalties_PG  DEF_Avg_Pen_Yds_PG  DEF_Avg_TOP  \
# 0                0.80          4.000000              52.364     0.526333
# 1                0.83          3.941176              55.000     0.488333
# 2                0.65          4.176471              50.455     0.484500
# 3                0.70          4.176471              50.182     0.489000
# 4                0.79          3.470588              43.800     0.487167
#
#    DEF_Fum_Lost_PG  Sacks_Taken_PG  Sack_Yds_Lost_PG  FG_Att_PG  FG_Good_PG  \
# 0         0.294118        1.705882         12.000000   1.235294    1.117647
# 1         0.294118        1.764706         12.411765   1.294118    1.235294
# 2         0.294118        1.588235          9.000000   1.352941    1.117647
# 3         0.529412        0.823529          4.470588   1.117647    0.941176
# 4         0.117647        2.294118         18.058824   1.176471    1.000000
#
#    Pass_Att_PG  DEF_Pass_Att_PG  DEF_Sacks_PG  DEF_Sack_Yds_PG  DEF_FG_Att_PG  \
# 0    20.529412        19.941176      1.882353        13.705882       1.235294
# 1    18.941176        19.000000      1.235294         8.294118       1.235294
# 2    18.235294        23.647059      2.588235        20.588235       1.470588
# 3    22.470588        21.058824      2.294118        13.411765       1.117647
# 4    22.235294        17.294118      1.000000         7.352941       0.882353
#
#    DEF_FG_Good_PG
# 0        1.058824
# 1        1.235294
# 2        1.411765
# 3        1.058824
# 4        0.882353

# %%
fun['OFF_Total Touchdowns'] = (fun['OFF_Total Touchdowns'] / fun['Games'])
# we want touchdowns per game
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'OFF_Total Touchdowns'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 fun['OFF_Total Touchdowns'] = (fun['OFF_Total Touchdowns'] / fun['Games'])
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'OFF_Total Touchdowns'

# %%
fun.rename(columns={'OFF_Total Touchdowns':'Tot_TDs_PG'}, inplace=True)
# rename column accordingly

# %%
fun.head()
# check to make sure it worked

# %%
fun['OFF_Total 1st downs'] = (fun['OFF_Total 1st downs'] / fun['Games'])

# %%
fun.rename(columns={'OFF_Total 1st downs':'1st_Downs_PG'}, inplace=True)

# %%
fun.head()

# %%
fun['OFF_Rushing 1st downs'] = (fun['OFF_Rushing 1st downs'] / fun['Games'])

# %%
fun.rename(columns={'OFF_Rushing 1st downs':'Rush_1st_Downs_PG'}, inplace=True)

# %%
fun.head()

# %%
fun['OFF_Passing 1st downs'] = (fun['OFF_Passing 1st downs'] / fun['Games'])

# %%
fun.rename(columns={'OFF_Passing 1st downs':'Pass_1st_Downs_PG'}, inplace=True)

# %%
fun.head()

# %%
fun['OFF_1st downs by penalty'] = (fun['OFF_1st downs by penalty'] / fun['Games'])

# %%
fun.rename(columns={'OFF_1st downs by penalty':'OFF_1st_by_pen_PG'}, inplace=True)

# %%
fun.head()

# %%
fun = fun.drop(columns='OFF_3rd down efficiency')

# %%
fun.rename(columns={'OFF_3rd down %':'3rd_Conv_rate'}, inplace=True)

# %%
fun.head()

# %%
fun = fun.drop(columns='OFF_4th down efficiency')

# %%
fun.rename(columns={'OFF_4th down %':'4th_Conv_Rate'}, inplace=True)

# %%
fun.head()

# %%
fun.rename(columns={'OFF_Comp-Att':'Pass_Comp_Rate'}, inplace=True)
# MUST ALSO TURN THIS INTO A RATE

# %%
fun.head()

# %%
# New Problem: We need to break up the string as two integers and divide one by the other to get a rate
# We will do this a few times so remember this methodology

# %%
test1 = fun['Pass_Comp_Rate'].str.split('-', expand=True)

# %%
type(test1[0][1])

# %%
test1 = test1.rename(columns={0:'Completed', 1:'Attempts'})

# %%
test1['Completed'] = test1['Completed'].astype(int)
test1['Attempts'] = test1['Attempts'].astype(int)

# %%
fun['Pass_Comp_Rate'] = test1['Completed'] / test1['Attempts']

# %%
fun.head()
# LETS GOOOOOO

# %%
# if len(testing) == 2:
#     comps = int(testing[0])
#     atts = int(testing[1])
#     if comps != 0:
#         done = comps / atts
#     else:
#         print('Error: division by zero')
# else:
#     print('Error: Invalid input string format')

# Not worth writing the loop lets just do it

# %%
fun.head()

# %%
fun.rename(columns={'OFF_Net Passing Yards':'Pass_Yds_PG'}, inplace=True)

# %%
fun['Pass_Yds_PG'] = (fun['Pass_Yds_PG'] / fun['Games'])

# %%
fun.head()

# %%
fun.rename(columns={'OFF_Yards Per Pass Attempt':'Pass_Yds_Per_Attempt'}, inplace=True)

# %%
fun.head()

# %%
fun = fun.drop(columns='OFF_Net Passing Yards Per Game')

# %%
fun.head()

# %%
fun.rename(columns={'OFF_Passing Touchdowns':'Pass_Tds_PG'}, inplace=True)

# %%
fun['Pass_Tds_PG'] = (fun['Pass_Tds_PG'] / fun['Games'])

# %%
fun.head()

# %%
fun.rename(columns={'OFF_Interceptions':'Off_Int_PG'}, inplace=True)

# %%
fun['Off_Int_PG'] = (fun['Off_Int_PG'] / fun['Games'])

# %%
fun.head()

# %%
fun.rename(columns={'OFF_Interceptions':'Off_Int_PG'}, inplace=True)

# %%
# REMEMBER TO COME BACK FOR OFF_SACKS-YARDS LOST

# %%
fun['OFF_Rushing Attempts'] = (fun['OFF_Rushing Attempts'] / fun['Games'])

# %%
fun.rename(columns={'OFF_Rushing Attempts':'Rush_Att_PG'}, inplace=True)

# %%
fun.head()

# %%
fun = fun.drop(columns='OFF_Rushing Yards')

# %%
fun.head()

# %%
fun.rename(columns={'OFF_Yards Per Rush Attempt':'Yds_Per_Rush'}, inplace=True)

# %%
fun.head()

# %%
fun.rename(columns={'OFF_Rushing Yards Per Game':'Rush_Yds_PG'}, inplace=True)

# %%
fun.head()

# %%
fun['OFF_Rushing Touchdowns'] = (fun['OFF_Rushing Touchdowns'] / fun['Games'])

# %%
fun.rename(columns={'OFF_Rushing Touchdowns':'Rush_Tds_PG'}, inplace=True)

# %%
fun.head()
# Out:
#             SeasonID   PPG  Tot_TDs_PG  1st_Downs_PG  Rush_1st_Downs_PG  \
# 0  Offense--ari-2023  17.5    1.176471     11.705882           4.176471
# 1  Offense--atl-2023  18.9    1.058824     11.705882           4.411765
# 2  Offense--bal-2023  27.6    2.058824     13.588235           5.764706
# 3  Offense--buf-2023  26.7    2.058824     14.235294           5.352941
# 4  Offense--car-2023  16.3    0.941176     10.941176           3.470588
#
#    Pass_1st_Downs_PG  OFF_1st_by_pen_PG  3rd_Conv_Rate  4th_Conv_Rate  \
# 0           6.294118           1.235294          35.29          27.27
# 1           6.470588           0.823529          41.43          46.15
# 2           6.294118           1.529412          44.60          42.86
# 3           7.882353           1.000000          48.12          54.55
# 4           6.117647           1.352941          37.24          56.52
#
#    Pass_Comp_Rate  Pass_Yds_PG  Pass_Yds_Per_Attempt  Pass_Tds_PG  Off_Int_PG  \
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'OFF_Total Offensive Plays'

# %%
fun.rename(columns={'OFF_Total Offensive Plays':'Off_Plays_PG'}, inplace=True)

# %%
fun.head()

# %%
fun = fun.drop(columns='OFF_Total Yards')

# %%
fun.rename(columns={'OFF_Yards Per Game':'Tot_Yds_PG'}, inplace=True)

# %%
fun.head()

# %%
# ignore 'OFF_Kickoffs: Total' again. Come back later
# ignore 'OFF_Punt: Total' for now and come back later

# %%
fun.rename(columns={'OFF_Average Kickoff Return Yards':'Avg_K_Return_Yds'}, inplace=True)

# %%
fun.rename(columns={'OFF_Average Punt Return Yards':'Avg_P_Return_Yds'}, inplace=True)

# %%
fun.head()

# %%
# COME BACK TO OFF_INT: TOTAL

# %%
fun.rename(columns={'OFF_Average Interception Yards':'Avg_I_Return_Yds'}, inplace=True)

# %%
fun.head()

# %%
fun.rename(columns={'OFF_Net Average Punt Yards':'Yds_Per_Punt'}, inplace=True)

# %%
fun.head()

# %%
# REMEMBER OFF_PUNT:TOTAL YARDS
# REMEMBER OFF_FG: Good-Attempts

# %%
fun.rename(columns={'OFF_Touchback Percentage':'Touchback_Rate'}, inplace=True)

# %%
fun.head()

# %%
fun.rename(columns={'OFF_Total-Yards':'Total_Penalties-Yds'}, inplace=True)

# %%
# REMEMBER TOTAL_PENALTIES-YDS

# %%
fun.head()

# %%
fun.rename(columns={'OFF_Avg. Per Game (YDS)':'Avg_Pen_Yds_PG'}, inplace=True)

# %%
fun.rename(columns={'OFF_Possession Time Seconds':'Avg_TOP'}, inplace=True)

# %%
fun.head()

# %%
# REMEMBER OFF_FUMBLES-LOST

# %%
fun = fun.drop(columns='OFF_Turnover Ratio')
# this column genuinely makes no sense according to ESPN's explanation
# because is it just a calculation of ints + fumbles on offense and defense,
# we can drop it since it will be redundant

# %%
fun.rename(columns={'OFF_Year':'Year'}, inplace=True)

# %%
fun.head()

# %%
fun.rename(columns={'3rd_Conv_rate':'3rd_Conv_Rate'}, inplace=True)

# %%
fun.rename(columns={'DEF_Total Points Per Game':'DEF_PPG_Against'}, inplace=True)

# %%
fun = fun.drop(columns='DEF_Total Points')

# %%
fun.head()

# %%
fun['DEF_Total Touchdowns'] = (fun['DEF_Total Touchdowns'] / fun['Games'])

# %%
fun.rename(columns={'DEF_Total Touchdowns':'DEF_Tot_Tds_PG_Against'}, inplace=True)

# %%
fun.head()

# %%
fun['DEF_Total 1st downs'] = (fun['DEF_Total 1st downs'] / fun['Games'])

# %%
fun.rename(columns={'DEF_Total 1st downs':'DEF_1st_Downs_PG_Against'}, inplace=True)

# %%
fun.head()

# %%
fun['DEF_Rushing 1st downs'] = (fun['DEF_Rushing 1st downs'] / fun['Games'])

# %%
fun.rename(columns={'DEF_Rushing 1st downs':'DEF_Rush_1st_Downs_PG_Against'}, inplace=True)

# %%
fun.head()

# %%
fun['DEF_Passing 1st downs'] = (fun['DEF_Passing 1st downs'] / fun['Games'])

# %%
fun.rename(columns={'DEF_Passing 1st downs':'DEF_Pass_1st_Downs_PG_Against'}, inplace=True)

# %%
fun.head()

# %%
fun['DEF_1st downs by penalty'] = (fun['DEF_1st downs by penalty'] / fun['Games'])

# %%
fun.rename(columns={'DEF_1st downs by penalty':'DEF_1st_by_pen_PG'}, inplace=True)

# %%
fun.head()

# %%
fun = fun.drop(columns='DEF_3rd down efficiency')

# %%
fun.rename(columns={'DEF_3rd down %':'DEF_3rd_Conv_Rate'}, inplace=True)

# %%
fun = fun.drop(columns='DEF_4th down efficiency')

# %%
fun.rename(columns={'DEF_4th down %':'DEF_4th_Conv_Rate'}, inplace=True)

# %%
fun.head()

# %%
# COME BACK TO DEF_COMP-ATT

# %%
fun.head()

# %%
fun = fun.drop(columns = 'DEF_Net Passing Yards')

# %%
fun.rename(columns={'DEF_Yards Per Pass Attempt':'DEF_Pass_Yds_Per_Attempt'}, inplace=True)

# %%
fun.head()

# %%
fun.rename(columns={'DEF_Net Passing Yards Per Game':'DEF_Pass_Yds_PG'}, inplace=True)

# %%
fun.head()

# %%
fun['DEF_Passing Touchdowns'] = fun['DEF_Passing Touchdowns'] / fun['Games']

# %%
fun.rename(columns={'DEF_Passing Touchdowns':'DEF_Pass_Tds_PG'}, inplace=True)

# %%
fun.head()

# %%
fun['DEF_Interceptions'] = fun['DEF_Interceptions'] / fun['Games']

# %%
fun.rename(columns={'DEF_Interceptions':'DEF_Int_PG'}, inplace=True)

# %%
fun['DEF_Rushing Attempts'] = fun['DEF_Rushing Attempts'] / fun['Games']

# %%
fun.rename(columns={'DEF_Rushing Attempts':'DEF_Rush_Att_PG'}, inplace=True)

# %%
fun.head()

# %%
def_cols = fun['DEF_Int_PG']
def_cols.head()

# %%
fun['DEF_Int_PG'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 32 entries, 0 to 31
# Series name: DEF_Int_PG
# Non-Null Count  Dtype
# --------------  -----
# 32 non-null     float64
# dtypes: float64(1)
# memory usage: 388.0 bytes

# %%
fun = fun.drop(columns='DEF_Rushing Yards')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 fun = fun.drop(columns='DEF_Rushing Yards')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['DEF_Rushing Yards'] not found in axis"

# %%
fun.rename(columns={'DEF_Rushing Yards Per Game':'DEF_Rush_Yds_PG'}, inplace=True)

# %%
fun.rename(columns={'DEF_Yards Per Rush Attempt':'DEF_Yds_Per_Rush'}, inplace=True)

# %%
fun.head()

# %%
fun['DEF_Rushing Touchdowns'] = fun['DEF_Rushing Touchdowns'] / fun['Games']

# %%
fun.rename(columns={'DEF_Rushing Touchdowns':'DEF_Rush_Tds_PG'}, inplace=True)

# %%
fun.head()

# %%
fun['DEF_Total Offensive Plays'] = fun['DEF_Total Offensive Plays'] / fun['Games']

# %%
fun.rename(columns={'DEF_Total Offensive Plays':'DEF_Tot_Plays_PG'}, inplace=True)

# %%
fun = fun.drop(columns = 'DEF_Total Yards')

# %%
fun.rename(columns={'DEF_Yards Per Game':'DEF_YPG_Against'}, inplace=True)

# %%
fun.head()

# %%
# Avg_K_Return_Yds

# %%
fun.rename(columns={'DEF_Average Kickoff Return Yards':'DEF_Avg_K_Return_Yds'}, inplace=True)

# %%
fun.rename(columns={'DEF_Average Punt Return Yards':'DEF_Avg_P_Return_Yds'}, inplace=True)

# %%
fun.rename(columns={'DEF_Average Interception Yards':'DEF_Avg_I_Return_Yds'}, inplace=True)

# %%
fun.head()

# %%
fun = fun.drop(columns = 'DEF_Games')

# %%
fun = fun.drop(columns = 'DEF_Turnover Ratio')

# %%
fun.head()

# %%
fun.rename(columns={'DEF_Net Average Punt Yards':'DEF_Yds_Per_Punt_Against'}, inplace=True)

# %%
fun.rename(columns={'DEF_Touchback Percentage':'DEF_Touchback_Rate'}, inplace=True)

# %%
fun.rename(columns={'DEF_Total-Yards':'DEF_Total_Penalties-Yds'}, inplace=True)

# %%
fun.head()
# Avg_Pen_Yds_PG

# %%
fun.rename(columns={'DEF_Avg. Per Game (YDS)':'DEF_Avg_Pen_Yds_PG'}, inplace=True)

# %%
fun.rename(columns={'DEF_Possession Time Seconds':'DEF_Avg_TOP'}, inplace=True)

# %%
fun.head()

# %% [markdown]
# ### We've left a number of columns untouched because they have multiple values within them. In some cases, both numbers provide valuable team information (example: sacks and yards lost by sacks). In other cases, calculations including both numbers provide valuable team information (completions and attempts can calculate completion percentage).
# Below is my process for dealing with these 'weird' columns

# %%
# So what's left?

# OFFENSE:
# 'OFF_Sacks-Yards Lost'
# 'OFF_Kickoffs: Total'
# 'OFF_Punt: Total'
# 'OFF_INT: Total'
# 'OFF_Punt: Total Yards'
# 'OFF_FG: Good-Attempts'
# 'Total_Penalties-Yds'
# 'OFF_Fumbles-Lost'

# DEFENSE
# 'DEF_Comp-Att'
# 'DEF_Sacks-Yards Lost'
# 'DEF_Kickoffs: Total'
# 'DEF_Punt: Total'
# 'DEF_INT: Total'
# 'DEF_Punt: Total Yards'
# 'DEF_FG: Good-Attempts'
# 'DEF_Total_Penalties-Yds'
# 'DEF_Fumbles-Lost'


# For all of these, we will do what we did to OFF_Comp-Att. The following is a basic template template...
#     tempDF = DF['Metric'].str.split('-', expanded=True)
#     rename columns in tempDF accordingly
#     change type from string to integer
#     set each column in tempDF to column in funDF
#     remove old column

# %%
pd.set_option('display.max_columns',None)
# displaying all columns for ease of manipulation. Not necessary

# %%
test2 = fun['OFF_Sacks-Yards Lost'].str.split('-', expand=True)
# creating a new dataframe with both sacks and yards lost from sacks

# %%
test2 = test2.rename(columns={0:'Sacks_Taken', 1:'Sack_Yds_Lost'})
# kind of unnecessary, but renames columns in new DF

# %%
test2.head()
# sanity check to make sure everything it good

# %%
test2['Sacks_Taken'] = test2['Sacks_Taken'].astype(int)
test2['Sack_Yds_Lost'] = test2['Sack_Yds_Lost'].astype(int)
# changing string to integer for later manipulation

# %%
fun['Sacks_Taken'] = test2['Sacks_Taken']
fun['Sack_Yds_Lost'] = test2['Sack_Yds_Lost']
# new columns in old df = columns from tempDF

# %%
fun = fun.drop(columns='OFF_Sacks-Yards Lost')

# %%
fun.head()

# %%
test3 = fun['OFF_Kickoffs: Total'].str.split('-', expand=True)

# %%
test3 = test3.rename(columns={0:'Kickoffs_Returned', 1:'Kickoff_Yds'})
test3.head()

# %%
test3['Kickoffs_Returned'] = test3['Kickoffs_Returned'].astype(int)
test3['Kickoff_Yds'] = test3['Kickoff_Yds'].astype(int)

# %%
fun['OFF_Kickoffs: Total'] = test3['Kickoffs_Returned']

# %%
fun['OFF_Kickoffs: Total'] = fun['OFF_Kickoffs: Total'] / fun['Games']

# %%
fun.rename(columns={'OFF_Kickoffs: Total':'Kickoffs_Returned'}, inplace=True)

# %%
fun.rename(columns={'Kickoffs_Returned':'Kickoffs_Returned_PG'}, inplace=True)

# %%
fun.head()

# %%
test4 = fun['OFF_Punt: Total'].str.split('-', expand=True)

# %%
test4 = test4.rename(columns={0:'Punts_Returned', 1:'Punt_Yds'})

# %%
test4['Punts_Returned'] = test4['Punts_Returned'].astype(int)

# %%
fun['OFF_Punt: Total'] = test4['Punts_Returned']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 fun['OFF_Punt: Total'] = test4['Punts_Returned']
#
# NameError: name 'test4' is not defined

# %%
fun['OFF_Punt: Total'] = fun['OFF_Punt: Total'] / fun['Games']

# %%
fun.rename(columns={'OFF_Punt: Total': 'Punts_Returned_PG'}, inplace=True)

# %%
fun.head()

# %%
test5 = fun['OFF_INT: Total'].str.split('-', expand=True)

# %%
test5 = test5.rename(columns={0:'Int_Forced_PG', 1:'WhoCares'})

# %%
test5['Int_Forced_PG'] = test5['Int_Forced_PG'].astype(int)

# %%
test5.head()

# %%
fun['OFF_INT: Total'] = test5['Int_Forced_PG']

# %%
fun.rename(columns={'OFF_INT: Total': "Int_Forced_PG"}, inplace=True)

# %%
fun['Int_Forced_PG'] = fun['Int_Forced_PG'] / fun['Games']

# %%
fun.head()

# %%
test6 = fun['OFF_Punt: Total Yards'].str.split('-', expand=True)

# %%
test6 = test6.rename(columns={0:'Punts', 1:'Yds'})

# %%
test6['Punts'] = test6['Punts'].astype(int)

# %%
fun['OFF_Punt: Total Yards'] = test6['Punts']

# %%
fun['OFF_Punt: Total Yards'] = fun['OFF_Punt: Total Yards'] / fun['Games']

# %%
fun.rename(columns={'OFF_Punt: Total Yards': 'Punts_PG'}, inplace = True)

# %%
fun.head()

# %%
test7 = fun['OFF_FG: Good-Attempts'].str.split('-', expand=True)

# %%
test7 = test7.rename(columns={0:'FG_Good', 1:'FG_Attempted'})
test7.head()

# %%
test7['FG_Good'] = test7['FG_Good'].astype(int)
test7['FG_Attempted'] = test7['FG_Attempted'].astype(int)

# %%
test7['FG_Conv_Rate'] = test7['FG_Good'] / test7['FG_Attempted']
test7.head()

# %%
fun['OFF_FG: Good-Attempts'] = test7['FG_Conv_Rate']

# %%
fun.rename(columns={'OFF_FG: Good-Attempts':'FG_Conv_Rate'}, inplace=True)

# %%
fun.head()

# %%
fun['FG_Att_PG'] = test7['FG_Attempted']

# %%
fun['FG_Good'] = test7['FG_Good']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 fun['FG_Good'] = test7['FG_Good']
#
# NameError: name 'test7' is not defined

# %%
fun['FG_Att_PG'] = fun['FG_Att_PG'] / fun['Games']

# %%
fun['FG_Good'] = fun['FG_Good'] / fun['Games']

# %%
fun.rename(columns={'FG_Good': 'FG_Good_PG'}, inplace=True)

# %%
fun.head()

# %%
test8 = fun['Total_Penalties-Yds'].str.split('-', expand=True)

# %%
test8 = test8.rename(columns={0:'Pen', 1:'Pen_Yds'})

# %%
test8.head()

# %%
test8['Pen'] = test8['Pen'].astype(int)

# %%
fun['Total_Penalties-Yds'] = test8['Pen']

# %%
fun['Total_Penalties-Yds'] = fun['Total_Penalties-Yds'] / fun['Games']

# %%
fun.rename(columns={'Total_Penalties-Yds': 'Penalties_PG'}, inplace=True)

# %%
fun.head()

# %%
fun = fun.drop(columns = 'OFF_index')

# %%
fun = fun.drop(columns = 'DEF_index')

# %%
# Still need to deal with:
# OFF_Fumbles-Lost
# DEF_Comp-Att
# DEF_Sacks-Yards Lost
# DEF_Kickoffs: Total
# DEF_Punt: Total
# DEF_INT: Total
# DEF_Punt: Total Yards
# DEF_FG: Good-Attempts
# DEF_Total_Penalties-Yds
# DEF_Fumbles-Lost

# %%
fun.head()
# Out:
#             SeasonID   PPG  Tot_TDs_PG  1st_Downs_PG  Rush_1st_Downs_PG  \
# 0  Offense--ari-2023  17.5    1.176471     11.705882           4.176471
# 1  Offense--atl-2023  18.9    1.058824     11.705882           4.411765
# 2  Offense--bal-2023  27.6    2.058824     13.588235           5.764706
# 3  Offense--buf-2023  26.7    2.058824     14.235294           5.352941
# 4  Offense--car-2023  16.3    0.941176     10.941176           3.470588
#
#    Pass_1st_Downs_PG  OFF_1st_by_pen_PG  3rd_Conv_Rate  4th_Conv_Rate  \
# 0           6.294118           1.235294          35.29          27.27
# 1           6.470588           0.823529          41.43          46.15
# 2           6.294118           1.529412          44.60          42.86
# 3           7.882353           1.000000          48.12          54.55
# 4           6.117647           1.352941          37.24          56.52
#
#    Pass_Comp_Rate  Pass_Yds_PG  Pass_Yds_Per_Attempt  Pass_Tds_PG  Off_Int_PG  \
# 0        0.624642   111.176471                   6.0     0.529412    0.529412
# 1        0.630435   120.529412                   7.0     0.529412    0.411765
# 2        0.693548   136.823529                   8.0     0.764706    0.294118
# 3        0.696335   164.647059                   7.5     1.294118    0.705882
# 4        0.616402   102.588235                   5.4     0.647059    0.470588
#
#    Rush_Att_PG  Yds_Per_Rush  Rush_Yds_PG  Rush_Tds_PG  Off_Plays_PG  \
# 0    17.058824           4.8        126.2     0.588235     39.294118
# 1    18.294118           4.2        130.4     0.529412     39.000000
# 2    20.882353           4.8        155.1     1.235294     40.705882
# 3    17.176471           4.4        117.7     0.705882     40.470588
# 4    13.823529           3.9         92.3     0.117647     38.352941
#
#    Tot_Yds_PG  Kickoffs_Returned_PG  Avg_K_Return_Yds  Punts_Returned_PG  \
# 0       316.5              0.588235              18.0           1.235294
# 1       356.4              0.529412              16.7           0.882353
# 2       380.5              0.470588              19.1           1.235294
# 3       379.1              0.588235              21.4           0.941176
# 4       297.4              0.705882              31.3           1.352941
#
#    Avg_P_Return_Yds  Int_Forced_PG  Avg_I_Return_Yds  Yds_Per_Punt  Punts_PG  \
# 0              10.1       0.470588              10.5          42.1  2.529412
# 1              12.6       0.294118               6.4          42.4  2.588235
# 2              13.4       0.588235              17.1          41.3  2.588235
# 3              11.9       0.588235               8.2          39.6  1.764706
# 4               6.6       0.294118              40.4          44.7  2.705882
#
#    FG_Conv_Rate  Touchback_Rate  Penalties_PG  Avg_Pen_Yds_PG   Avg_TOP  \
# 0      0.904762            0.85      4.352941              62  0.466833
# 1      0.954545            0.83      3.176471              49  0.504833
# 2      0.826087            0.85      4.000000              58  0.523333
# 3      0.842105            0.58      4.294118              56  0.505000
# 4      0.850000            0.63      4.117647              55  0.506000
#
#    Fum_Lost_PG  Games  DEF_PPG_Against  DEF_Tot_Tds_PG_Against  \
# 0     0.352941     17             25.8                1.941176
# 1     0.529412     17             21.7                1.294118
# 2     0.529412     17             16.1                0.882353
# 3     0.411765     17             17.3                1.176471
# 4     0.294118     17             27.5                1.941176
#
#    DEF_1st_Downs_PG_Against  DEF_Rush_1st_Downs_PG_Against  \
# 0                 14.411765                       5.411765
# 1                 10.705882                       3.235294
# 2                 11.352941                       3.588235
# 3                 12.000000                       3.294118
# 4                 11.764706                       4.588235
#
#    DEF_Pass_1st_Downs_PG_Against  DEF_1st_by_pen_PG  DEF_3rd_Conv_Rate  \
# 0                       7.647059           1.352941              46.76
# 1                       6.294118           1.176471              34.38
# 2                       6.235294           1.529412              35.19
# 3                       7.294118           1.411765              38.62
# 4                       6.058824           1.117647              36.51
#
#    DEF_4th_Conv_Rate  DEF_Pass_Comp_Rate  DEF_Pass_Yds_Per_Attempt  \
# 0              36.36            0.696165                       7.7
# 1              50.00            0.628483                       6.6
# 2              36.84            0.599502                       5.5
# 3              56.25            0.678771                       6.9
# 4              71.43            0.656463                       6.5
#
#    DEF_Pass_Yds_PG  DEF_Pass_Tds_PG  DEF_Int_PG  DEF_Rush_Att_PG  \
# 0            217.5         1.000000    0.470588        20.235294
# 1            200.4         1.000000    0.294118        16.235294
# 2            169.7         0.529412    0.588235        15.705882
# 3            204.2         0.764706    0.588235        15.764706
# 4            179.2         0.764706    0.294118        17.764706
#
#    DEF_Yds_Per_Rush  DEF_Rush_Yds_PG  DEF_Rush_Tds_PG  DEF_Tot_Plays_PG  \
# 0               4.2            132.1         0.882353         42.058824
# 1               3.9            108.4         0.235294         36.470588
# 2               4.3            103.7         0.235294         41.941176
# 3               4.5            110.5         0.352941         39.117647
# 4               4.3            129.4         0.941176         36.058824
#
#    DEF_YPG_Against  DEF_Kickoffs_Returned_PG  DEF_Avg_K_Return_Yds  \
# 0            370.7                  0.176471                  21.0
# 1            322.9                  0.411765                  21.9
# 2            305.3                  0.529412                  22.1
# 3            335.4                  1.352941                  20.4
# 4            321.1                  0.588235                  24.7
#
#    DEF_Punts_Returned_PG  DEF_Avg_P_Return_Yds  DEF_Avg_I_Return_Yds  \
# 0               1.764706                   9.9                   4.6
# 1               1.117647                   5.3                  16.9
# 2               1.235294                  13.0                  10.8
# 3               0.764706                   9.3                   5.5
# 4               1.058824                   9.7                  20.6
#
#    DEF_Yds_Per_Punt_Against  DEF_Punts_PG  DEF_FG_Conv_Rate  \
# 0                      43.5      2.352941          0.857143
# 1                      46.1      2.764706          1.000000
# 2                      41.1      3.235294          0.960000
# 3                      45.1      2.588235          0.947368
# 4                      43.2      2.588235          1.000000
#
#    DEF_Touchback_Rate  DEF_Penalties_PG  DEF_Avg_Pen_Yds_PG  DEF_Avg_TOP  \
# 0                0.80          4.000000              52.364     0.526333
# 1                0.83          3.941176              55.000     0.488333
# 2                0.65          4.176471              50.455     0.484500
# 3                0.70          4.176471              50.182     0.489000
# 4                0.79          3.470588              43.800     0.487167
#
#    DEF_Fum_Lost_PG  Sacks_Taken_PG  Sack_Yds_Lost_PG  FG_Att_PG  FG_Good_PG  \
# 0         0.294118        1.705882         12.000000   1.235294    1.117647
# 1         0.294118        1.764706         12.411765   1.294118    1.235294
# 2         0.294118        1.588235          9.000000   1.352941    1.117647
# 3         0.529412        0.823529          4.470588   1.117647    0.941176
# 4         0.117647        2.294118         18.058824   1.176471    1.000000
#
#    Pass_Att_PG  DEF_Pass_Att_PG  DEF_Sacks_PG  DEF_Sack_Yds_PG  DEF_FG_Att_PG  \
# 0    20.529412        19.941176      1.882353        13.705882       1.235294
# 1    18.941176        19.000000      1.235294         8.294118       1.235294
# 2    18.235294        23.647059      2.588235        20.588235       1.470588
# 3    22.470588        21.058824      2.294118        13.411765       1.117647
# 4    22.235294        17.294118      1.000000         7.352941       0.882353
#
#    DEF_FG_Good_PG
# 0        1.058824
# 1        1.235294
# 2        1.411765
# 3        1.058824
# 4        0.882353

# %%
test9 = fun['OFF_Fumbles-Lost'].str.split('-', expand=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'OFF_Fumbles-Lost'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 test9 = fun['OFF_Fumbles-Lost'].str.split('-', expand=True)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'OFF_Fumbles-Lost'

# %%
test9 = test9.rename(columns={0:'Tot_Fum', 1:'Fum_Lost'})
test9.head()

# %%
test9['Fum_Lost'] = test9['Fum_Lost'].astype(int)

# %%
fun['OFF_Fumbles-Lost'] = test9['Fum_Lost']

# %%
fun['OFF_Fumbles-Lost'] = fun['OFF_Fumbles-Lost'] / fun['Games']

# %%
fun.rename(columns={'OFF_Fumbles-Lost': 'Fum_Lost_PG'}, inplace=True)

# %%
fun.head()

# %%
test1.head()
# upon viewing defensive statistics, I decided that passing attempts per
# game was valuable information, so I am going back and adding it...

# %%
fun['Pass_Att_PG'] = test1['Attempts']

# %%
fun['Pass_Att_PG'] = fun['Pass_Att_PG'] / fun['Games']

# %%
fun.head()

# %%
test10 = fun['DEF_Comp-Att'].str.split('-', expand=True)

# %%
test10 = test10.rename(columns={0:'Completed', 1:'Attempts'})

# %%
test10.head()

# %%
test10['Completed'] = test10['Completed'].astype(int)
test10['Attempts'] = test10['Attempts'].astype(int)

# %%
fun['DEF_Comp-Att'] = test10['Completed'] / test10['Attempts']

# %%
fun.rename(columns={'DEF_Comp-Att':'DEF_Pass_Comp_Rate'}, inplace=True)

# %%
fun['DEF_Pass_Att_PG'] = test10['Attempts']

# %%
fun['DEF_Pass_Att_PG'] = fun['DEF_Pass_Att_PG'] / fun['Games']

# %%
fun.head()

# %%
test12 = fun['DEF_Sacks-Yards Lost'].str.split('-', expand=True)

# %%
test12 = test12.rename(columns={0:'Sacks_Taken', 1:'Sack_Yds_Lost'})

# %%
test12.head()

# %%
test12['Sacks_Taken'] = test12['Sacks_Taken'].astype(int)
test12['Sack_Yds_Lost'] = test12['Sack_Yds_Lost'].astype(int)

# %%
fun['DEF_Sacks_PG'] = test12['Sacks_Taken']
fun['DEF_Sack_Yds_PG'] = test12['Sack_Yds_Lost']

# %%
fun['DEF_Sacks_PG'] = fun['DEF_Sacks_PG'] / fun['Games']

# %%
fun['DEF_Sack_Yds_PG'] = fun['DEF_Sack_Yds_PG'] / fun['Games']

# %%
fun = fun.drop(columns='DEF_Sacks-Yards Lost')

# %%
# I realized that I forgot to divide the OFF columns by games, so lets
# do that now....

# %%
fun.head()

# %%
fun['Sacks_Taken'] = fun['Sacks_Taken'] / fun['Games']

# %%
fun['Sack_Yds_Lost'] = fun['Sack_Yds_Lost'] / fun['Games']

# %%
fun.rename(columns={'Sacks_Taken':'Sacks_Taken_PG'}, inplace=True)

# %%
fun.rename(columns={'Sack_Yds_Lost':'Sack_Yds_Lost_PG'}, inplace=True)

# %%
fun.head()

# %%
test13 = fun['DEF_Kickoffs: Total'].str.split('-', expand=True)

# %%
test13 = test13.rename(columns={0:'Kickoffs_Returned', 1:'Kickoff_Yds'})
test13.head()

# %%
test13['Kickoffs_Returned'] = test13['Kickoffs_Returned'].astype(int)
test13['Kickoff_Yds'] = test13['Kickoff_Yds'].astype(int)

# %%
fun['DEF_Kickoffs: Total'] = test13['Kickoffs_Returned']

# %%
fun['DEF_Kickoffs: Total'] = fun['DEF_Kickoffs: Total'] / fun['Games']

# %%
fun.rename(columns={'DEF_Kickoffs: Total':'DEF_Kickoffs_Returned_PG'}, inplace=True)

# %%
fun.tail()
# wow, interesting that are returning significantly more kickoffs now than 2004

# %%
test14 = fun['DEF_Punt: Total'].str.split('-', expand=True)

# %%
test14 = test14.rename(columns={0:'Punts_Returned', 1:'Punt_Yds'})

# %%
test14['Punts_Returned'] = test14['Punts_Returned'].astype(int)

# %%
fun['DEF_Punt: Total'] = test14['Punts_Returned']

# %%
fun['DEF_Punt: Total'] = fun['DEF_Punt: Total'] / fun['Games']

# %%
fun.rename(columns={'DEF_Punt: Total': 'DEF_Punts_Returned_PG'}, inplace=True)

# %%
fun.head()

# %%
# After naming issues, I found out these columns are redundant, so I'm just going to drop it
# test15 = fun['DEF_INT: Total'].str.split('-', expand=True)

# %%
# test15 = test15.rename(columns={0:'Int_Forced_PG', 1:'Nope'})

# %%
# test15.head()

# %%
# test15['Int_Forced_PG'] = test15['Int_Forced_PG'].astype(int)

# %%
# test15['Int_Forced_PG'].info()

# %%
# fun.head()

# %%
# test15.head()

# %%
# fun['DEF_INT: Total'] = test15['Int_Forced_PG']

# %%
# fun['Int_Forced_PG'].head()

# %%
# fun.rename(columns={'DEF_INT: Total': "DEF_Int_PG"}, inplace=True)

# %%
# fun.head()

# %%
# fun['DEF_Int_PG'] = fun['DEF_Int_PG'] / fun['Games']

# %%
fun.head()

# %%
fun.drop(columns='DEF_INT: Total')

# %%
test16 = fun['DEF_Punt: Total Yards'].str.split('-', expand=True)

# %%
test16 = test16.rename(columns={0:'APunts', 1:'AYds'})

# %%
test16['APunts'] = test16['APunts'].astype(int)

# %%
fun['DEF_Punt: Total Yards'] = test16['APunts']

# %%
fun['DEF_Punt: Total Yards'] = fun['DEF_Punt: Total Yards'] / fun['Games']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DEF_Punt: Total Yards'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 fun['DEF_Punt: Total Yards'] = fun['DEF_Punt: Total Yards'] / fun['Games']
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'DEF_Punt: Total Yards'

# %%
fun.rename(columns={'DEF_Punt: Total Yards': 'DEF_Punts_PG'}, inplace = True)

# %%
fun.head()

# %%
fun = fun.drop(columns='DEF_INT: Total')

# %%
fun.head()
# if you are reading this, this is around the part of the feature engineering where I lost my mind

# %%
test17 = fun['DEF_FG: Good-Attempts'].str.split('-', expand=True)

# %%
test17 = test17.rename(columns={0:'FG_Good', 1:'FG_Attempted'})
test17.head()

# %%
test17['FG_Good'] = test17['FG_Good'].astype(int)
test17['FG_Attempted'] = test17['FG_Attempted'].astype(int)

# %%
test17['FG_Conv_Rate'] = test17['FG_Good'] / test17['FG_Attempted']
test17.head()

# %%
fun['DEF_FG: Good-Attempts'] = test17['FG_Conv_Rate']

# %%
fun.rename(columns={'DEF_FG: Good-Attempts':'DEF_FG_Conv_Rate'}, inplace=True)

# %%
fun.head()

# %%
fun['DEF_FG_Att_PG'] = test17['FG_Attempted']

# %%
fun['DEF_FG_Good'] = test17['FG_Good']

# %%
fun['DEF_FG_Att_PG'] = fun['DEF_FG_Att_PG'] / fun['Games']

# %%
fun['DEF_FG_Good'] = fun['DEF_FG_Good'] / fun['Games']

# %%
fun.rename(columns={'DEF_FG_Good': 'DEF_FG_Good_PG'}, inplace=True)

# %%
fun.head()

# %%
test18 = fun['DEF_Total_Penalties-Yds'].str.split('-', expand=True)

# %%
test18 = test18.rename(columns={0:'Pen', 1:'Pen_Yds'})

# %%
test18['Pen'] = test18['Pen'].astype(int)

# %%
fun['DEF_Total_Penalties-Yds'] = test18['Pen']

# %%
fun['DEF_Total_Penalties-Yds'] = fun['DEF_Total_Penalties-Yds'] / fun['Games']

# %%
fun.rename(columns={'DEF_Total_Penalties-Yds': 'DEF_Penalties_PG'}, inplace=True)

# %%
fun.head()

# %%
test19 = fun['DEF_Fumbles-Lost'].str.split('-', expand=True)

# %%
test19 = test19.rename(columns={0:'Tot_Fum', 1:'Fum_Lost'})
test19.head()

# %%
test19['Fum_Lost'] = test19['Fum_Lost'].astype(int)

# %%
fun['DEF_Fumbles-Lost'] = test19['Fum_Lost']

# %%
fun['DEF_Fumbles-Lost'] = fun['DEF_Fumbles-Lost'] / fun['Games']

# %%
fun.rename(columns={'DEF_Fumbles-Lost': 'DEF_Fum_Lost_PG'}, inplace=True)

# %%
# omg am i done?
fun.head()

# %%
fun['Avg_TOP'] = fun['Avg_TOP'].replace(':','', regex=True)

# %%
fun['Avg_TOP'].info()

# %%
fun['Avg_TOP'] = fun['Avg_TOP'].astype(int)

# %%
fun['Avg_TOP'] = fun['Avg_TOP'] / 6000

# %%
fun['Avg_TOP'].head()

# %%
fun.head()

# %%
fun['DEF_Avg_TOP'] = fun['DEF_Avg_TOP'].replace(':','', regex=True)

# %%
fun['DEF_Avg_TOP'] = fun['DEF_Avg_TOP'].astype(int)

# %%
fun['DEF_Avg_TOP'] = fun['DEF_Avg_TOP'] / 6000

# %%
fun.head()

# %%
fun['Touchback_Rate'] = fun['Touchback_Rate'] / 100

# %%
fun['DEF_Touchback_Rate'] = fun['DEF_Touchback_Rate'] / 100

# %%
fun.head()

# %%
fun.shape

# %%
fun.info()

# %%
fun.isna().sum()

# %%
fun.head()

# %%
import pandas as pd
import numpy as np
from itertools import combinations
from itertools import permutations
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fun.to_csv('In-Season_2023_Week13.csv', index=False)
# this is the CSV for EDA

# %%
fun = pd.read_csv('/Users/justintunley/Documents/BrainStation/Capstone/In-Season_2023_Week11.csv')
# THIS IS A DIFFERENT DATASET SO BE WARNED

# %%
yearList = ['2023']

# %%
# this is for modeling predictions
final_list = []

for year in yearList:
    temp_df = fun.loc[fun['SeasonID'].str.contains(year),:]

    combinations_list = list(permutations(temp_df.iterrows(), 2))

    pairs_data = []
    for pair in combinations_list:
        index1, row1 = pair[0]
        index2, row2 = pair[1]

        # Combine rows and add a distinction between sides
        pair_data = list(row1) + list(row2)
        #pair_data.extend([f'{col}_Team2' for col in y04.columns])

        pairs_data.append(pair_data)

    # Create column names for the new dataframe
    columns = [f'{col}_Team1' for col in temp_df.columns] + [f'{col}_Team2' for col in temp_df.columns]

    # Create the new dataframe
    pairs_df2 = pd.DataFrame(pairs_data, columns=columns)

    final_list.append(pairs_df2)

# %%
final_list

# %%
merged = pd.concat(final_list)
merged.head()

# %%
merged['season'] = 2023

# %%
merged.head()

# %%
merged.shape

# %%
merged.to_csv('Week13_modeling.csv', index=False)

# %% [markdown]
# This is the end of this notebook. There is additional EDA below but further modeling steps can be found in my modeling notebooks.

# %% [markdown]
# # EDA on Current-Season Data

# %%
EDA = pd.read_csv('/Users/justintunley/Documents/BrainStation/Capstone/In-Season_2023_Week11.csv')

# %%
EDA.head()

# %%
EDA['PPG'].describe()
# Teams score on average 22.36 points per game
# Means PT O/U will be around 45

# %%
EDA['DEF_PPG_Against'].describe()
# Shouldn't these be relatively similar?

# %%
EDA['PPG'].plot(kind='hist')
plt.title('Distribution of PPG')
plt.xlabel('Average PPG')
plt.ylabel('Count')
# Normal distribution, not clear skew

# %%
EDA.groupby('PPG')['Pass_Tds_PG'].value_counts(normalize=True).unstack().plot(kind='barh', stacked=True)

# %%
corr_mat = EDA.corr()
corr_mat
# Correlation matrix demonstrating how features interact with each other and the target variable

# %%
EDA['PPG'].describe()
